# %%
import sys
import re
import pymongo
import json
import time
import datetime
import requests
from bs4 import BeautifulSoup

dbname = "fdac18mp2" #please use this database
collname = "mmprj_jdunca51" #please modify so you store data in your collection
my_char = 't'

# beginning page index
begin = "1"
client = pymongo.MongoClient()

db = client[dbname]
coll = db[collname]


gitlab_url = "https://gitlab.com/api/v4/projects?archived=false&membership=false&order_by=created_at&owned=false&page=" + begin + \
    "&per_page=99&simple=false&sort=desc&starred=false&statistics=false&with_custom_attributes=false&with_issues_enabled=false&with_merge_requests_enabled=false"

gleft = 20

source_url = "https://sourceforge.net/directory/?q=" + my_char + "&sort=name&page="
rest_url = "https://sourceforge.net/rest/p/"

header = {'per_page': 99}

# check remaining query chances for rate-limit restriction
def wait(left):
    global header
    while (left < 20):
        l = requests.get('https://gitlab.com/api/v4/projects', headers=header)
        if (l.ok):
            left = int(l.headers.get('RateLimit-Remaining'))
        time .sleep(60)
    return left

def project_exists(url):
    r = requests.get(url)
    if r.status_code == 200:
        return True
    return False

def get_source(url, coll, rest):
    page = 1
    project_count = 0
    while True:
        resp = requests.get(url + str(page))
        text = resp.text
        soup = BeautifulSoup(text, 'html.parser')
        if re.search('No results found.', soup.get_text()):
            return

        for link in soup.find_all(class_="project-icon", href=True):
            name = re.findall('/projects/([A-Za-z0-9\-]*)', link.get('href'))
            name = name[0] if name else None
            if name is not None and name.lower().startswith(my_char):
                resp = requests.get(rest + name)
                if resp.status_code == 200:
                    info = json.loads(resp.text)
                    info['forge'] = 'sourceforge'
                    coll.insert_one(info)
                    project_count += 1
                    if project_count >= 50:
                        return
        page += 1
    return

# send queries and extract urls 
def get_gitlab(url, coll):

    global gleft
    global header
    global bginnum
    gleft = wait(gleft)
    values = []
    size = 0
    project_count = 0

    try:
        r = requests .get(url, headers=header)
        time .sleep(0.5)
        # got blocked
        if r.status_code == 403:
            return "got blocked", str(bginnum)
        if (r.ok):

            gleft = int(r.headers.get('RateLimit-Remaining'))
            lll = r.headers.get('Link')
            t = r.text
            array = json.loads(t)
            
            for el in array:
                if el['name'].lower().startswith(my_char):
                    if project_exists(el['http_url_to_repo']):
                        project_count += 1
                        el['forge'] = 'gitlab'
                        coll.insert_one(el)
                        if project_count >= 50:
                            return
            
            #next page
            while ('; rel="next"' in lll):
                gleft = int(r.headers.get('RateLimit-Remaining'))
                gleft = wait(gleft)
                # extract next page url
                ll = lll.replace(';', ',').split(',')
                url = ll[ll.index(' rel="next"') -
                         1].replace('<', '').replace('>', '').lstrip()
             
                try:
                    r = requests .get(url, headers=header)
                    if r.status_code == 403:
                        return "got blocked", str(bginnum)
                    if (r.ok):
                        lll = r.headers.get('Link')
                        t = r.text
                        array1 = json.loads(t)
                        for el in array1:
                            if el['name'].lower().startswith(my_char):
                                if project_exists(el['http_url_to_repo']):
                                    project_count += 1
                                    el['forge'] = 'gitlab'
                                    coll.insert_one(el)
                                    if project_count >= 50:
                                        return
                    else:
                        sys.stderr.write("url can not found:\n" + url + '\n')
                        return 
                except requests.exceptions.ConnectionError:
                    sys.stderr.write('could not get ' + url + '\n')
            
        else:
            sys.stderr.write("url can not found:\n" + url + '\n')
            return

    except requests.exceptions.ConnectionError:
        sys.stderr.write('could not get ' + url + '\n')
    except Exception as e:
        sys.stderr.write(url + ';' + str(e) + '\n')
        
#start retrieving        
get_gitlab(gitlab_url,coll)
get_source(source_url, coll, rest_url)

# %%
#print collected data
for doc in coll.find({}):
    print(doc)
# Out:
# {'id': 8874489, '_id': ObjectId('5bc4b3ecf0537b13284762dd'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:juniorziger2018/tvhdfull.git', 'http_url_to_repo': 'https://gitlab.com/juniorziger2018/tvhdfull.git', 'created_at': '2018-10-15T15:18:20.308Z', 'web_url': 'https://gitlab.com/juniorziger2018/tvhdfull', 'name': 'TV HD FULL', 'namespace': {'id': 3810496, 'kind': 'user', 'parent_id': None, 'path': 'juniorziger2018', 'full_path': 'juniorziger2018', 'name': 'juniorziger2018'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': None, 'path_with_namespace': 'juniorziger2018/tvhdfull', 'last_activity_at': '2018-10-15T15:18:20.308Z', 'forks_count': 0, 'path': 'tvhdfull', 'tag_list': [], 'name_with_namespace': 'Junior Ziger / TV HD FULL', 'description': ''}
# {'id': 8874459, '_id': ObjectId('5bc4b3ecf0537b13284762de'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:moverperfect/Track-Video-Watching-From-Email.git', 'http_url_to_repo': 'https://gitlab.com/moverperfect/Track-Video-Watching-From-Email.git', 'created_at': '2018-10-15T15:16:10.849Z', 'web_url': 'https://gitlab.com/moverperfect/Track-Video-Watching-From-Email', 'name': 'Track-Video-Watching-From-Email', 'namespace': {'id': 360227, 'kind': 'user', 'parent_id': None, 'path': 'moverperfect', 'full_path': 'moverperfect', 'name': 'moverperfect'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/moverperfect/Track-Video-Watching-From-Email/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'moverperfect/Track-Video-Watching-From-Email', 'last_activity_at': '2018-10-15T15:16:10.849Z', 'forks_count': 0, 'path': 'Track-Video-Watching-From-Email', 'tag_list': [], 'name_with_namespace': 'Jack Moorhouse / Track-Video-Watching-From-Email', 'description': None}
# {'id': 8874458, '_id': ObjectId('5bc4b3edf0537b13284762df'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:moverperfect/Track-Video-Watching.git', 'http_url_to_repo': 'https://gitlab.com/moverperfect/Track-Video-Watching.git', 'created_at': '2018-10-15T15:16:10.362Z', 'web_url': 'https://gitlab.com/moverperfect/Track-Video-Watching', 'name': 'Track-Video-Watching', 'namespace': {'id': 360227, 'kind': 'user', 'parent_id': None, 'path': 'moverperfect', 'full_path': 'moverperfect', 'name': 'moverperfect'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/moverperfect/Track-Video-Watching/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'moverperfect/Track-Video-Watching', 'last_activity_at': '2018-10-15T15:16:10.362Z', 'forks_count': 0, 'path': 'Track-Video-Watching', 'tag_list': [], 'name_with_namespace': 'Jack Moorhouse / Track-Video-Watching', 'description': 'ASP.Net website to track video watching'}
# {'id': 8874424, '_id': ObjectId('5bc4b3edf0537b13284762e0'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:DangTruong1997/trandangtruong.git', 'http_url_to_repo': 'https://gitlab.com/DangTruong1997/trandangtruong.git', 'created_at': '2018-10-15T15:14:39.834Z', 'web_url': 'https://gitlab.com/DangTruong1997/trandangtruong', 'name': 'TranDangTruong', 'namespace': {'id': 3767412, 'kind': 'user', 'parent_id': None, 'path': 'DangTruong1997', 'full_path': 'DangTruong1997', 'name': 'DangTruong1997'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'DangTruong1997/trandangtruong', 'last_activity_at': '2018-10-15T15:14:39.834Z', 'forks_count': 0, 'path': 'trandangtruong', 'tag_list': [], 'name_with_namespace': 'tran dang truong / TranDangTruong', 'description': ''}
# {'id': 8874419, '_id': ObjectId('5bc4b3edf0537b13284762e1'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:QuantumDE/tryton-documentation.git', 'http_url_to_repo': 'https://gitlab.com/QuantumDE/tryton-documentation.git', 'created_at': '2018-10-15T15:14:13.141Z', 'web_url': 'https://gitlab.com/QuantumDE/tryton-documentation', 'name': 'tryton-documentation', 'namespace': {'id': 3014886, 'kind': 'group', 'parent_id': None, 'path': 'QuantumDE', 'full_path': 'QuantumDE', 'name': 'QuantumDE'}, 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8874419/3724976.png', 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/QuantumDE/tryton-documentation/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'QuantumDE/tryton-documentation', 'last_activity_at': '2018-10-15T15:14:13.141Z', 'forks_count': 0, 'path': 'tryton-documentation', 'tag_list': [], 'name_with_namespace': 'QuantumDE / tryton-documentation', 'description': 'tryton documentation'}
# {'id': 8874396, '_id': ObjectId('5bc4b3eef0537b13284762e2'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:UbikBSD/ServerSide/trytond-gis.git', 'http_url_to_repo': 'https://gitlab.com/UbikBSD/ServerSide/trytond-gis.git', 'created_at': '2018-10-15T15:12:33.947Z', 'web_url': 'https://gitlab.com/UbikBSD/ServerSide/trytond-gis', 'name': 'trytond-gis', 'namespace': {'id': 3505285, 'kind': 'group', 'parent_id': 3014851, 'path': 'ServerSide', 'full_path': 'UbikBSD/ServerSide', 'name': 'ServerSide'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/UbikBSD/ServerSide/trytond-gis/blob/develop/README', 'default_branch': 'develop', 'path_with_namespace': 'UbikBSD/ServerSide/trytond-gis', 'last_activity_at': '2018-10-15T15:12:33.947Z', 'forks_count': 0, 'path': 'trytond-gis', 'tag_list': [], 'name_with_namespace': 'UbikBSD / ServerSide / trytond-gis', 'description': 'tryton daemon GIS related module'}
# {'id': 8874312, '_id': ObjectId('5bc4b3eef0537b13284762e3'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:slavanap/test-writefile-winapi.git', 'http_url_to_repo': 'https://gitlab.com/slavanap/test-writefile-winapi.git', 'created_at': '2018-10-15T15:07:27.559Z', 'web_url': 'https://gitlab.com/slavanap/test-writefile-winapi', 'name': 'Test WriteFile WinAPI', 'namespace': {'id': 2257951, 'kind': 'user', 'parent_id': None, 'path': 'slavanap', 'full_path': 'slavanap', 'name': 'slavanap'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'slavanap/test-writefile-winapi', 'last_activity_at': '2018-10-15T15:07:27.559Z', 'forks_count': 0, 'path': 'test-writefile-winapi', 'tag_list': [], 'name_with_namespace': 'Vyacheslav Napadovsky / Test WriteFile WinAPI', 'description': ''}
# {'id': 8874234, '_id': ObjectId('5bc4b3eef0537b13284762e4'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:Troopavhs/thekingsreturn.git', 'http_url_to_repo': 'https://gitlab.com/Troopavhs/thekingsreturn.git', 'created_at': '2018-10-15T15:03:07.760Z', 'web_url': 'https://gitlab.com/Troopavhs/thekingsreturn', 'name': 'TheKingsReturn', 'namespace': {'id': 2358747, 'kind': 'user', 'parent_id': None, 'path': 'Troopavhs', 'full_path': 'Troopavhs', 'name': 'Troopavhs'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/Troopavhs/thekingsreturn/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'Troopavhs/thekingsreturn', 'last_activity_at': '2018-10-15T15:03:07.760Z', 'forks_count': 0, 'path': 'thekingsreturn', 'tag_list': [], 'name_with_namespace': 'Thomas Bourgeois / TheKingsReturn', 'description': ''}
# {'id': 8874176, '_id': ObjectId('5bc4b3fff0537b13284762e5'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:dongzhuoer/teaching_book-output.git', 'http_url_to_repo': 'https://gitlab.com/dongzhuoer/teaching_book-output.git', 'created_at': '2018-10-15T15:01:14.406Z', 'web_url': 'https://gitlab.com/dongzhuoer/teaching_book-output', 'name': 'teaching_book-output', 'namespace': {'id': 2652841, 'kind': 'user', 'parent_id': None, 'path': 'dongzhuoer', 'full_path': 'dongzhuoer', 'name': 'dongzhuoer'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/dongzhuoer/teaching_book-output/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'dongzhuoer/teaching_book-output', 'last_activity_at': '2018-10-15T15:01:14.406Z', 'forks_count': 0, 'path': 'teaching_book-output', 'tag_list': [], 'name_with_namespace': 'Zhuoer Dong / teaching_book-output', 'description': 'Example plain HTML site using GitLab Pages: https://pages.gitlab.io/plain-html'}
# {'id': 8874137, '_id': ObjectId('5bc4b400f0537b13284762e6'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:link867/task_tracker.git', 'http_url_to_repo': 'https://gitlab.com/link867/task_tracker.git', 'created_at': '2018-10-15T14:59:31.675Z', 'web_url': 'https://gitlab.com/link867/task_tracker', 'name': 'task_tracker', 'namespace': {'id': 1806979, 'kind': 'user', 'parent_id': None, 'path': 'link867', 'full_path': 'link867', 'name': 'link867'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'link867/task_tracker', 'last_activity_at': '2018-10-15T14:59:31.675Z', 'forks_count': 0, 'path': 'task_tracker', 'tag_list': [], 'name_with_namespace': 'link867 / task_tracker', 'description': 'Small task tracking client with a hook to excel'}
# {'id': 8874105, '_id': ObjectId('5bc4b400f0537b13284762e7'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:Yahill/test.git', 'http_url_to_repo': 'https://gitlab.com/Yahill/test.git', 'created_at': '2018-10-15T14:57:54.337Z', 'web_url': 'https://gitlab.com/Yahill/test', 'name': 'test', 'namespace': {'id': 2778997, 'kind': 'user', 'parent_id': None, 'path': 'Yahill', 'full_path': 'Yahill', 'name': 'Yahill'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/Yahill/test/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'Yahill/test', 'last_activity_at': '2018-10-15T14:57:54.337Z', 'forks_count': 0, 'path': 'test', 'tag_list': [], 'name_with_namespace': 'Vladimir / test', 'description': ''}
# {'id': 8874058, '_id': ObjectId('5bc4b400f0537b13284762e8'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:sohaibazed/TensorFlow-Course.git', 'http_url_to_repo': 'https://gitlab.com/sohaibazed/TensorFlow-Course.git', 'created_at': '2018-10-15T14:55:22.359Z', 'web_url': 'https://gitlab.com/sohaibazed/TensorFlow-Course', 'name': 'Tensor-flow', 'namespace': {'id': 3018758, 'kind': 'user', 'parent_id': None, 'path': 'sohaibazed', 'full_path': 'sohaibazed', 'name': 'sohaibazed'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/sohaibazed/TensorFlow-Course/blob/master/README.rst', 'default_branch': 'master', 'path_with_namespace': 'sohaibazed/TensorFlow-Course', 'last_activity_at': '2018-10-15T14:55:22.359Z', 'forks_count': 0, 'path': 'TensorFlow-Course', 'tag_list': [], 'name_with_namespace': 'sohaib azed / Tensor-flow', 'description': ''}
# {'id': 8874050, '_id': ObjectId('5bc4b401f0537b13284762e9'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:vbotka/TLS-Attacker.git', 'http_url_to_repo': 'https://gitlab.com/vbotka/TLS-Attacker.git', 'created_at': '2018-10-15T14:55:03.134Z', 'web_url': 'https://gitlab.com/vbotka/TLS-Attacker', 'name': 'TLS-Attacker', 'namespace': {'id': 3809998, 'kind': 'user', 'parent_id': None, 'path': 'vbotka', 'full_path': 'vbotka', 'name': 'vbotka'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/vbotka/TLS-Attacker/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'vbotka/TLS-Attacker', 'last_activity_at': '2018-10-15T14:55:03.134Z', 'forks_count': 0, 'path': 'TLS-Attacker', 'tag_list': [], 'name_with_namespace': 'Vladimir Botka / TLS-Attacker', 'description': 'TLS-Attacker is a Java-based framework for analyzing TLS libraries. It is developed by the Ruhr University Bochum (http://nds.rub.de/) and the Hackmanit GmbH (http://hackmanit.de/). '}
# {'id': 8874046, '_id': ObjectId('5bc4b401f0537b13284762ea'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:vbotka/thesis-data.git', 'http_url_to_repo': 'https://gitlab.com/vbotka/thesis-data.git', 'created_at': '2018-10-15T14:55:02.690Z', 'web_url': 'https://gitlab.com/vbotka/thesis-data', 'name': 'thesis-data', 'namespace': {'id': 3809998, 'kind': 'user', 'parent_id': None, 'path': 'vbotka', 'full_path': 'vbotka', 'name': 'vbotka'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/vbotka/thesis-data/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'vbotka/thesis-data', 'last_activity_at': '2018-10-15T14:55:02.690Z', 'forks_count': 0, 'path': 'thesis-data', 'tag_list': [], 'name_with_namespace': 'Vladimir Botka / thesis-data', 'description': 'Experimental data of the thesis'}
# {'id': 8874045, '_id': ObjectId('5bc4b401f0537b13284762eb'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:vbotka/thesis.git', 'http_url_to_repo': 'https://gitlab.com/vbotka/thesis.git', 'created_at': '2018-10-15T14:55:01.966Z', 'web_url': 'https://gitlab.com/vbotka/thesis', 'name': 'thesis', 'namespace': {'id': 3809998, 'kind': 'user', 'parent_id': None, 'path': 'vbotka', 'full_path': 'vbotka', 'name': 'vbotka'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/vbotka/thesis/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'vbotka/thesis', 'last_activity_at': '2018-10-15T14:55:01.966Z', 'forks_count': 0, 'path': 'thesis', 'tag_list': [], 'name_with_namespace': 'Vladimir Botka / thesis', 'description': 'Doctoral Thesis: Electrophysical properties of the MOS structure with implanted bulk'}
# {'id': 8873976, '_id': ObjectId('5bc4b406f0537b13284762ec'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:s1618joe/test.git', 'http_url_to_repo': 'https://gitlab.com/s1618joe/test.git', 'created_at': '2018-10-15T14:53:52.881Z', 'web_url': 'https://gitlab.com/s1618joe/test', 'name': 'test', 'namespace': {'id': 3555340, 'kind': 'user', 'parent_id': None, 'path': 's1618joe', 'full_path': 's1618joe', 'name': 's1618joe'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/s1618joe/test/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 's1618joe/test', 'last_activity_at': '2018-10-15T14:53:52.881Z', 'forks_count': 0, 'path': 'test', 'tag_list': [], 'name_with_namespace': 'Yen, ChiWen / test', 'description': ''}
# {'id': 8873845, '_id': ObjectId('5bc4b407f0537b13284762ed'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:sbidel/test-simulateur-vue.git', 'http_url_to_repo': 'https://gitlab.com/sbidel/test-simulateur-vue.git', 'created_at': '2018-10-15T14:47:34.008Z', 'web_url': 'https://gitlab.com/sbidel/test-simulateur-vue', 'name': 'test-simulateur-vue', 'namespace': {'id': 3093360, 'kind': 'user', 'parent_id': None, 'path': 'sbidel', 'full_path': 'sbidel', 'name': 'sbidel'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/sbidel/test-simulateur-vue/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'sbidel/test-simulateur-vue', 'last_activity_at': '2018-10-15T14:47:34.008Z', 'forks_count': 0, 'path': 'test-simulateur-vue', 'tag_list': [], 'name_with_namespace': 'Sylvain Bidel / test-simulateur-vue', 'description': ''}
# {'id': 8873822, '_id': ObjectId('5bc4b407f0537b13284762ee'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:dinizelizio/treinamento-elizio.git', 'http_url_to_repo': 'https://gitlab.com/dinizelizio/treinamento-elizio.git', 'created_at': '2018-10-15T14:46:52.952Z', 'web_url': 'https://gitlab.com/dinizelizio/treinamento-elizio', 'name': 'Treinamento Elizio', 'namespace': {'id': 2476088, 'kind': 'user', 'parent_id': None, 'path': 'dinizelizio', 'full_path': 'dinizelizio', 'name': 'dinizelizio'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/dinizelizio/treinamento-elizio/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'dinizelizio/treinamento-elizio', 'last_activity_at': '2018-10-15T14:46:52.952Z', 'forks_count': 0, 'path': 'treinamento-elizio', 'tag_list': [], 'name_with_namespace': 'Elizio Rodrigues Lima Carneiro Diniz / Treinamento Elizio', 'description': 'Treinamento.'}
# {'id': 8873791, '_id': ObjectId('5bc4b407f0537b13284762ef'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:sbidel/test-simulateur-ng.git', 'http_url_to_repo': 'https://gitlab.com/sbidel/test-simulateur-ng.git', 'created_at': '2018-10-15T14:45:40.447Z', 'web_url': 'https://gitlab.com/sbidel/test-simulateur-ng', 'name': 'test-simulateur-ng', 'namespace': {'id': 3093360, 'kind': 'user', 'parent_id': None, 'path': 'sbidel', 'full_path': 'sbidel', 'name': 'sbidel'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/sbidel/test-simulateur-ng/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'sbidel/test-simulateur-ng', 'last_activity_at': '2018-10-15T14:45:40.447Z', 'forks_count': 0, 'path': 'test-simulateur-ng', 'tag_list': [], 'name_with_namespace': 'Sylvain Bidel / test-simulateur-ng', 'description': ''}
# {'id': 8873741, '_id': ObjectId('5bc4b407f0537b13284762f0'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:s.a.roberts/testing-app-repo.git', 'http_url_to_repo': 'https://gitlab.com/s.a.roberts/testing-app-repo.git', 'created_at': '2018-10-15T14:44:03.718Z', 'web_url': 'https://gitlab.com/s.a.roberts/testing-app-repo', 'name': 'testing app repo', 'namespace': {'id': 3810308, 'kind': 'user', 'parent_id': None, 'path': 's.a.roberts', 'full_path': 's.a.roberts', 'name': 's.a.roberts'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/s.a.roberts/testing-app-repo/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 's.a.roberts/testing-app-repo', 'last_activity_at': '2018-10-15T14:44:03.718Z', 'forks_count': 0, 'path': 'testing-app-repo', 'tag_list': [], 'name_with_namespace': 'Sean Roberts / testing app repo', 'description': ''}
# {'id': 8873565, '_id': ObjectId('5bc4b40df0537b13284762f1'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:anibaka/tets-repo.git', 'http_url_to_repo': 'https://gitlab.com/anibaka/tets-repo.git', 'created_at': '2018-10-15T14:38:27.970Z', 'web_url': 'https://gitlab.com/anibaka/tets-repo', 'name': 'Tets repo', 'namespace': {'id': 1927536, 'kind': 'user', 'parent_id': None, 'path': 'anibaka', 'full_path': 'anibaka', 'name': 'anibaka'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': None, 'path_with_namespace': 'anibaka/tets-repo', 'last_activity_at': '2018-10-15T14:38:27.970Z', 'forks_count': 0, 'path': 'tets-repo', 'tag_list': [], 'name_with_namespace': 'Aleksey Budkin / Tets repo', 'description': ''}
# {'id': 8873525, '_id': ObjectId('5bc4b40df0537b13284762f2'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:stranniknm/test.git', 'http_url_to_repo': 'https://gitlab.com/stranniknm/test.git', 'created_at': '2018-10-15T14:36:01.472Z', 'web_url': 'https://gitlab.com/stranniknm/test', 'name': 'test', 'namespace': {'id': 129512, 'kind': 'user', 'parent_id': None, 'path': 'stranniknm', 'full_path': 'stranniknm', 'name': 'stranniknm'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/stranniknm/test/blob/RN/README.md', 'default_branch': 'RN', 'path_with_namespace': 'stranniknm/test', 'last_activity_at': '2018-10-15T14:36:01.472Z', 'forks_count': 0, 'path': 'test', 'tag_list': [], 'name_with_namespace': 'Aydar Farrakhov / test', 'description': ''}
# {'id': 8873353, '_id': ObjectId('5bc4b40ef0537b13284762f3'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:siddhata_aspl/total-sms-clone.git', 'http_url_to_repo': 'https://gitlab.com/siddhata_aspl/total-sms-clone.git', 'created_at': '2018-10-15T14:27:44.817Z', 'web_url': 'https://gitlab.com/siddhata_aspl/total-sms-clone', 'name': 'Total SMS Clone', 'namespace': {'id': 2653030, 'kind': 'user', 'parent_id': None, 'path': 'siddhata_aspl', 'full_path': 'siddhata_aspl', 'name': 'siddhata_aspl'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': None, 'path_with_namespace': 'siddhata_aspl/total-sms-clone', 'last_activity_at': '2018-10-15T14:27:44.817Z', 'forks_count': 0, 'path': 'total-sms-clone', 'tag_list': [], 'name_with_namespace': 'siddhata / Total SMS Clone', 'description': ''}
# {'id': 8873225, '_id': ObjectId('5bc4b412f0537b13284762f4'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:misc0x10/test-repo.git', 'http_url_to_repo': 'https://gitlab.com/misc0x10/test-repo.git', 'created_at': '2018-10-15T14:20:22.372Z', 'web_url': 'https://gitlab.com/misc0x10/test-repo', 'name': 'Test-Repo', 'namespace': {'id': 3768847, 'kind': 'user', 'parent_id': None, 'path': 'misc0x10', 'full_path': 'misc0x10', 'name': 'misc0x10'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/misc0x10/test-repo/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'misc0x10/test-repo', 'last_activity_at': '2018-10-15T14:20:22.372Z', 'forks_count': 0, 'path': 'test-repo', 'tag_list': [], 'name_with_namespace': 'misc0x10 / Test-Repo', 'description': ''}
# {'id': 8873144, '_id': ObjectId('5bc4b412f0537b13284762f5'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:meltano/target-csv.git', 'http_url_to_repo': 'https://gitlab.com/meltano/target-csv.git', 'created_at': '2018-10-15T14:16:55.084Z', 'web_url': 'https://gitlab.com/meltano/target-csv', 'name': 'target-csv', 'namespace': {'id': 2524164, 'kind': 'group', 'parent_id': None, 'path': 'meltano', 'full_path': 'meltano', 'name': 'meltano'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/meltano/target-csv/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'meltano/target-csv', 'last_activity_at': '2018-10-15T14:16:55.084Z', 'forks_count': 0, 'path': 'target-csv', 'tag_list': [], 'name_with_namespace': 'meltano / target-csv', 'description': ''}
# {'id': 8873052, '_id': ObjectId('5bc4b412f0537b13284762f6'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:ahmed.elbarbri33/taxi_degla.git', 'http_url_to_repo': 'https://gitlab.com/ahmed.elbarbri33/taxi_degla.git', 'created_at': '2018-10-15T14:14:02.812Z', 'web_url': 'https://gitlab.com/ahmed.elbarbri33/taxi_degla', 'name': 'Taxi_Degla', 'namespace': {'id': 3760595, 'kind': 'user', 'parent_id': None, 'path': 'ahmed.elbarbri33', 'full_path': 'ahmed.elbarbri33', 'name': 'ahmed.elbarbri33'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'ahmed.elbarbri33/taxi_degla', 'last_activity_at': '2018-10-15T14:14:02.812Z', 'forks_count': 0, 'path': 'taxi_degla', 'tag_list': [], 'name_with_namespace': 'Ahmed EL-barbri / Taxi_Degla', 'description': ''}
# {'id': 8872966, '_id': ObjectId('5bc4b413f0537b13284762f7'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:ROUKIEN/tictrack.git', 'http_url_to_repo': 'https://gitlab.com/ROUKIEN/tictrack.git', 'created_at': '2018-10-15T14:11:24.304Z', 'web_url': 'https://gitlab.com/ROUKIEN/tictrack', 'name': 'tictrack', 'namespace': {'id': 907499, 'kind': 'user', 'parent_id': None, 'path': 'ROUKIEN', 'full_path': 'ROUKIEN', 'name': 'ROUKIEN'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/ROUKIEN/tictrack/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'ROUKIEN/tictrack', 'last_activity_at': '2018-10-15T14:11:24.304Z', 'forks_count': 0, 'path': 'tictrack', 'tag_list': [], 'name_with_namespace': 'Rukien / tictrack', 'description': 'Track your topics speaking time during your meetings'}
# {'id': 8872858, '_id': ObjectId('5bc4b413f0537b13284762f8'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:dewey-dot/terrain.git', 'http_url_to_repo': 'https://gitlab.com/dewey-dot/terrain.git', 'created_at': '2018-10-15T14:07:26.322Z', 'web_url': 'https://gitlab.com/dewey-dot/terrain', 'name': 'terrain', 'namespace': {'id': 3609329, 'kind': 'group', 'parent_id': None, 'path': 'dewey-dot', 'full_path': 'dewey-dot', 'name': ' The Dewey-Dot Foundation. '}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': None, 'path_with_namespace': 'dewey-dot/terrain', 'last_activity_at': '2018-10-15T14:07:26.322Z', 'forks_count': 0, 'path': 'terrain', 'tag_list': [], 'name_with_namespace': ' The Dewey-Dot Foundation.  / terrain', 'description': '(Weak Pun On Train) Collection Of Mods & An Associated Game-Mode For Terasology To Build Up Some Basic Programming & Electronics Skills; Eventually Want To Plan A MOOC Around This.\r\n'}
# {'id': 8872796, '_id': ObjectId('5bc4b417f0537b13284762f9'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:A_FLOOD/task1.git', 'http_url_to_repo': 'https://gitlab.com/A_FLOOD/task1.git', 'created_at': '2018-10-15T14:04:48.133Z', 'web_url': 'https://gitlab.com/A_FLOOD/task1', 'name': 'task1', 'namespace': {'id': 3083573, 'kind': 'user', 'parent_id': None, 'path': 'A_FLOOD', 'full_path': 'A_FLOOD', 'name': 'A_FLOOD'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': None, 'path_with_namespace': 'A_FLOOD/task1', 'last_activity_at': '2018-10-15T14:04:48.133Z', 'forks_count': 0, 'path': 'task1', 'tag_list': [], 'name_with_namespace': 'Alexander / task1', 'description': ''}
# {'id': 8871892, '_id': ObjectId('5bc4b421f0537b13284762fa'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:usernameddd/test.git', 'http_url_to_repo': 'https://gitlab.com/usernameddd/test.git', 'created_at': '2018-10-15T13:18:49.732Z', 'web_url': 'https://gitlab.com/usernameddd/test', 'name': 'test', 'namespace': {'id': 3809612, 'kind': 'user', 'parent_id': None, 'path': 'usernameddd', 'full_path': 'usernameddd', 'name': 'usernameddd'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': None, 'path_with_namespace': 'usernameddd/test', 'last_activity_at': '2018-10-15T13:18:49.732Z', 'forks_count': 0, 'path': 'test', 'tag_list': [], 'name_with_namespace': 'usernameddd / test', 'description': '测试项目'}
# {'id': 8871683, '_id': ObjectId('5bc4b422f0537b13284762fb'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:gerald.duveau/transactional-email-templates.git', 'http_url_to_repo': 'https://gitlab.com/gerald.duveau/transactional-email-templates.git', 'created_at': '2018-10-15T13:07:33.021Z', 'web_url': 'https://gitlab.com/gerald.duveau/transactional-email-templates', 'name': 'transactional-email-templates', 'namespace': {'id': 3808577, 'kind': 'user', 'parent_id': None, 'path': 'gerald.duveau', 'full_path': 'gerald.duveau', 'name': 'gerald.duveau'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/gerald.duveau/transactional-email-templates/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'gerald.duveau/transactional-email-templates', 'last_activity_at': '2018-10-15T13:07:33.021Z', 'forks_count': 0, 'path': 'transactional-email-templates', 'tag_list': [], 'name_with_namespace': 'gérald / transactional-email-templates', 'description': 'Responsive transactional HTML email templates'}
# {'id': 8871583, '_id': ObjectId('5bc4b422f0537b13284762fc'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:QuantumDE/TrytonModules/timesheet.git', 'http_url_to_repo': 'https://gitlab.com/QuantumDE/TrytonModules/timesheet.git', 'created_at': '2018-10-15T13:01:56.179Z', 'web_url': 'https://gitlab.com/QuantumDE/TrytonModules/timesheet', 'name': 'timesheet', 'namespace': {'id': 3809505, 'kind': 'group', 'parent_id': 3014886, 'path': 'TrytonModules', 'full_path': 'QuantumDE/TrytonModules', 'name': 'TrytonModules'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/QuantumDE/TrytonModules/timesheet/blob/develop/README', 'default_branch': 'develop', 'path_with_namespace': 'QuantumDE/TrytonModules/timesheet', 'last_activity_at': '2018-10-15T13:01:56.179Z', 'forks_count': 0, 'path': 'timesheet', 'tag_list': [], 'name_with_namespace': 'QuantumDE / TrytonModules / timesheet', 'description': 'timesheet module'}
# {'id': 8871561, '_id': ObjectId('5bc4b427f0537b13284762fd'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:QuantumDE/TrytonModules/timesheet_cost.git', 'http_url_to_repo': 'https://gitlab.com/QuantumDE/TrytonModules/timesheet_cost.git', 'created_at': '2018-10-15T13:00:39.050Z', 'web_url': 'https://gitlab.com/QuantumDE/TrytonModules/timesheet_cost', 'name': 'timesheet_cost', 'namespace': {'id': 3809505, 'kind': 'group', 'parent_id': 3014886, 'path': 'TrytonModules', 'full_path': 'QuantumDE/TrytonModules', 'name': 'TrytonModules'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/QuantumDE/TrytonModules/timesheet_cost/blob/develop/README', 'default_branch': 'develop', 'path_with_namespace': 'QuantumDE/TrytonModules/timesheet_cost', 'last_activity_at': '2018-10-15T13:00:39.050Z', 'forks_count': 0, 'path': 'timesheet_cost', 'tag_list': [], 'name_with_namespace': 'QuantumDE / TrytonModules / timesheet_cost', 'description': 'timesheet cost module'}
# {'id': 8871427, '_id': ObjectId('5bc4b427f0537b13284762fe'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:krische/test.git', 'http_url_to_repo': 'https://gitlab.com/krische/test.git', 'created_at': '2018-10-15T12:51:19.027Z', 'web_url': 'https://gitlab.com/krische/test', 'name': 'test', 'namespace': {'id': 18682, 'kind': 'user', 'parent_id': None, 'path': 'krische', 'full_path': 'krische', 'name': 'krische'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/krische/test/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'krische/test', 'last_activity_at': '2018-10-15T12:51:19.027Z', 'forks_count': 0, 'path': 'test', 'tag_list': [], 'name_with_namespace': 'Brian Krische / test', 'description': ''}
# {'id': 8871084, '_id': ObjectId('5bc4b42cf0537b13284762ff'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:BananaRay/tomat.git', 'http_url_to_repo': 'https://gitlab.com/BananaRay/tomat.git', 'created_at': '2018-10-15T12:33:19.702Z', 'web_url': 'https://gitlab.com/BananaRay/tomat', 'name': 'tomat', 'namespace': {'id': 3809353, 'kind': 'user', 'parent_id': None, 'path': 'BananaRay', 'full_path': 'BananaRay', 'name': 'BananaRay'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'BananaRay/tomat', 'last_activity_at': '2018-10-15T13:33:34.765Z', 'forks_count': 0, 'path': 'tomat', 'tag_list': [], 'name_with_namespace': 'Evgeniy Gorokhov / tomat', 'description': ''}
# {'id': 8870942, '_id': ObjectId('5bc4b42cf0537b1328476300'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:PatrickUMH/tarea9.git', 'http_url_to_repo': 'https://gitlab.com/PatrickUMH/tarea9.git', 'created_at': '2018-10-15T12:28:54.678Z', 'web_url': 'https://gitlab.com/PatrickUMH/tarea9', 'name': 'Tarea9', 'namespace': {'id': 3358190, 'kind': 'user', 'parent_id': None, 'path': 'PatrickUMH', 'full_path': 'PatrickUMH', 'name': 'PatrickUMH'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'PatrickUMH/tarea9', 'last_activity_at': '2018-10-15T12:28:54.678Z', 'forks_count': 0, 'path': 'tarea9', 'tag_list': [], 'name_with_namespace': 'Patrick Uriel Mendoza Hernández / Tarea9', 'description': ''}
# {'id': 8870488, '_id': ObjectId('5bc4b431f0537b1328476301'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:COchs/todo-app-experiments.git', 'http_url_to_repo': 'https://gitlab.com/COchs/todo-app-experiments.git', 'created_at': '2018-10-15T12:00:00.410Z', 'web_url': 'https://gitlab.com/COchs/todo-app-experiments', 'name': 'Todo App Experiments', 'namespace': {'id': 431484, 'kind': 'user', 'parent_id': None, 'path': 'COchs', 'full_path': 'COchs', 'name': 'COchs'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'COchs/todo-app-experiments', 'last_activity_at': '2018-10-15T12:00:00.410Z', 'forks_count': 0, 'path': 'todo-app-experiments', 'tag_list': [], 'name_with_namespace': 'Christopher Ochs / Todo App Experiments', 'description': ''}
# {'id': 8869765, '_id': ObjectId('5bc4b435f0537b1328476302'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:anisch01/testgit.git', 'http_url_to_repo': 'https://gitlab.com/anisch01/testgit.git', 'created_at': '2018-10-15T11:18:30.854Z', 'web_url': 'https://gitlab.com/anisch01/testgit', 'name': 'testgit', 'namespace': {'id': 3807888, 'kind': 'user', 'parent_id': None, 'path': 'anisch01', 'full_path': 'anisch01', 'name': 'anisch01'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'anisch01/testgit', 'last_activity_at': '2018-10-15T11:18:30.854Z', 'forks_count': 0, 'path': 'testgit', 'tag_list': [], 'name_with_namespace': 'Anis chourasia / testgit', 'description': ''}
# {'id': 8868758, '_id': ObjectId('5bc4b444f0537b1328476303'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:myontars/TelveTroll.git', 'http_url_to_repo': 'https://gitlab.com/myontars/TelveTroll.git', 'created_at': '2018-10-15T10:27:55.985Z', 'web_url': 'https://gitlab.com/myontars/TelveTroll', 'name': 'TelveTroll', 'namespace': {'id': 1845377, 'kind': 'user', 'parent_id': None, 'path': 'myontars', 'full_path': 'myontars', 'name': 'myontars'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/myontars/TelveTroll/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'myontars/TelveTroll', 'last_activity_at': '2018-10-15T10:27:55.985Z', 'forks_count': 0, 'path': 'TelveTroll', 'tag_list': [], 'name_with_namespace': 'Mustafa / TelveTroll', 'description': None}
# {'id': 8868696, '_id': ObjectId('5bc4b445f0537b1328476304'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:karanrajpal14/trydjango19.git', 'http_url_to_repo': 'https://gitlab.com/karanrajpal14/trydjango19.git', 'created_at': '2018-10-15T10:23:26.483Z', 'web_url': 'https://gitlab.com/karanrajpal14/trydjango19', 'name': 'trydjango19', 'namespace': {'id': 289074, 'kind': 'user', 'parent_id': None, 'path': 'karanrajpal14', 'full_path': 'karanrajpal14', 'name': 'karanrajpal14'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'karanrajpal14/trydjango19', 'last_activity_at': '2018-10-15T10:23:26.483Z', 'forks_count': 0, 'path': 'trydjango19', 'tag_list': [], 'name_with_namespace': 'Karan Rajpal / trydjango19', 'description': 'A demo Django blog developed for learning purposes using https://www.youtube.com/playlist?list=PLEsfXFp6DpzQFqfCur9CJ4QnKQTVXUsRy'}
# {'id': 8868066, '_id': ObjectId('5bc4b44af0537b1328476305'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:sunitaku/training_sdet.git', 'http_url_to_repo': 'https://gitlab.com/sunitaku/training_sdet.git', 'created_at': '2018-10-15T09:46:15.277Z', 'web_url': 'https://gitlab.com/sunitaku/training_sdet', 'name': 'Training_SDET', 'namespace': {'id': 3776640, 'kind': 'user', 'parent_id': None, 'path': 'sunitaku', 'full_path': 'sunitaku', 'name': 'sunitaku'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'sunitaku/training_sdet', 'last_activity_at': '2018-10-15T13:04:53.094Z', 'forks_count': 0, 'path': 'training_sdet', 'tag_list': [], 'name_with_namespace': 'Sunita Kumari / Training_SDET', 'description': ''}
# {'id': 8867926, '_id': ObjectId('5bc4b44af0537b1328476306'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:johnny_huang/test.git', 'http_url_to_repo': 'https://gitlab.com/johnny_huang/test.git', 'created_at': '2018-10-15T09:38:32.078Z', 'web_url': 'https://gitlab.com/johnny_huang/test', 'name': 'test', 'namespace': {'id': 2492699, 'kind': 'user', 'parent_id': None, 'path': 'johnny_huang', 'full_path': 'johnny_huang', 'name': 'johnny_huang'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/johnny_huang/test/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'johnny_huang/test', 'last_activity_at': '2018-10-15T09:38:32.078Z', 'forks_count': 0, 'path': 'test', 'tag_list': [], 'name_with_namespace': 'Johnny Huang / test', 'description': None}
# {'id': 8867778, '_id': ObjectId('5bc4b44bf0537b1328476307'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:xopowen/task-2.git', 'http_url_to_repo': 'https://gitlab.com/xopowen/task-2.git', 'created_at': '2018-10-15T09:31:08.743Z', 'web_url': 'https://gitlab.com/xopowen/task-2', 'name': 'task 2', 'namespace': {'id': 3605233, 'kind': 'user', 'parent_id': None, 'path': 'xopowen', 'full_path': 'xopowen', 'name': 'xopowen'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'xopowen/task-2', 'last_activity_at': '2018-10-15T09:31:08.743Z', 'forks_count': 0, 'path': 'task-2', 'tag_list': [], 'name_with_namespace': 'Женя Хороших / task 2', 'description': ''}
# {'id': 8867734, '_id': ObjectId('5bc4b44bf0537b1328476308'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/typescript-cli-starter.git', 'http_url_to_repo': 'https://gitlab.com/kindlychung/typescript-cli-starter.git', 'created_at': '2018-10-15T09:27:59.250Z', 'web_url': 'https://gitlab.com/kindlychung/typescript-cli-starter', 'name': 'typescript-cli-starter', 'namespace': {'id': 633660, 'kind': 'user', 'parent_id': None, 'path': 'kindlychung', 'full_path': 'kindlychung', 'name': 'kindlychung'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'kindlychung/typescript-cli-starter', 'last_activity_at': '2018-10-15T09:27:59.250Z', 'forks_count': 0, 'path': 'typescript-cli-starter', 'tag_list': [], 'name_with_namespace': 'Kaiyin Zhong / typescript-cli-starter', 'description': None}
# {'id': 8867733, '_id': ObjectId('5bc4b44bf0537b1328476309'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/twitter-elm-wall.git', 'http_url_to_repo': 'https://gitlab.com/kindlychung/twitter-elm-wall.git', 'created_at': '2018-10-15T09:27:58.947Z', 'web_url': 'https://gitlab.com/kindlychung/twitter-elm-wall', 'name': 'twitter-elm-wall', 'namespace': {'id': 633660, 'kind': 'user', 'parent_id': None, 'path': 'kindlychung', 'full_path': 'kindlychung', 'name': 'kindlychung'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/kindlychung/twitter-elm-wall/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'kindlychung/twitter-elm-wall', 'last_activity_at': '2018-10-15T09:27:58.947Z', 'forks_count': 0, 'path': 'twitter-elm-wall', 'tag_list': [], 'name_with_namespace': 'Kaiyin Zhong / twitter-elm-wall', 'description': 'Tweeter Elm Wall'}
# {'id': 8867714, '_id': ObjectId('5bc4b44cf0537b132847630a'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/typescript-express-starter.git', 'http_url_to_repo': 'https://gitlab.com/kindlychung/typescript-express-starter.git', 'created_at': '2018-10-15T09:27:49.998Z', 'web_url': 'https://gitlab.com/kindlychung/typescript-express-starter', 'name': 'typescript-express-starter', 'namespace': {'id': 633660, 'kind': 'user', 'parent_id': None, 'path': 'kindlychung', 'full_path': 'kindlychung', 'name': 'kindlychung'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/kindlychung/typescript-express-starter/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'kindlychung/typescript-express-starter', 'last_activity_at': '2018-10-15T09:27:49.998Z', 'forks_count': 0, 'path': 'typescript-express-starter', 'tag_list': [], 'name_with_namespace': 'Kaiyin Zhong / typescript-express-starter', 'description': 'TypeScript 2 + Express + Node.js'}
# {'id': 8867713, '_id': ObjectId('5bc4b44cf0537b132847630b'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/txtutils.git', 'http_url_to_repo': 'https://gitlab.com/kindlychung/txtutils.git', 'created_at': '2018-10-15T09:27:49.851Z', 'web_url': 'https://gitlab.com/kindlychung/txtutils', 'name': 'txtutils', 'namespace': {'id': 633660, 'kind': 'user', 'parent_id': None, 'path': 'kindlychung', 'full_path': 'kindlychung', 'name': 'kindlychung'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/kindlychung/txtutils/blob/master/readme.md', 'default_branch': 'master', 'path_with_namespace': 'kindlychung/txtutils', 'last_activity_at': '2018-10-15T09:27:49.851Z', 'forks_count': 0, 'path': 'txtutils', 'tag_list': [], 'name_with_namespace': 'Kaiyin Zhong / txtutils', 'description': 'An auxiliary R package'}
# {'id': 8867712, '_id': ObjectId('5bc4b44cf0537b132847630c'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/tup.git', 'http_url_to_repo': 'https://gitlab.com/kindlychung/tup.git', 'created_at': '2018-10-15T09:27:49.682Z', 'web_url': 'https://gitlab.com/kindlychung/tup', 'name': 'tup', 'namespace': {'id': 633660, 'kind': 'user', 'parent_id': None, 'path': 'kindlychung', 'full_path': 'kindlychung', 'name': 'kindlychung'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/kindlychung/tup/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'kindlychung/tup', 'last_activity_at': '2018-10-15T09:27:49.682Z', 'forks_count': 0, 'path': 'tup', 'tag_list': [], 'name_with_namespace': 'Kaiyin Zhong / tup', 'description': 'Tup is a file-based build system.'}
# {'id': 8867711, '_id': ObjectId('5bc4b44df0537b132847630d'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/transText.git', 'http_url_to_repo': 'https://gitlab.com/kindlychung/transText.git', 'created_at': '2018-10-15T09:27:49.468Z', 'web_url': 'https://gitlab.com/kindlychung/transText', 'name': 'transText', 'namespace': {'id': 633660, 'kind': 'user', 'parent_id': None, 'path': 'kindlychung', 'full_path': 'kindlychung', 'name': 'kindlychung'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'kindlychung/transText', 'last_activity_at': '2018-10-15T09:27:49.468Z', 'forks_count': 0, 'path': 'transText', 'tag_list': [], 'name_with_namespace': 'Kaiyin Zhong / transText', 'description': 'Translation tool between Dutch, French and English'}
# {'id': 8867710, '_id': ObjectId('5bc4b44df0537b132847630e'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:kindlychung/translator.git', 'http_url_to_repo': 'https://gitlab.com/kindlychung/translator.git', 'created_at': '2018-10-15T09:27:49.344Z', 'web_url': 'https://gitlab.com/kindlychung/translator', 'name': 'translator', 'namespace': {'id': 633660, 'kind': 'user', 'parent_id': None, 'path': 'kindlychung', 'full_path': 'kindlychung', 'name': 'kindlychung'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/kindlychung/translator/blob/master/README.rst', 'default_branch': 'master', 'path_with_namespace': 'kindlychung/translator', 'last_activity_at': '2018-10-15T09:27:49.344Z', 'forks_count': 0, 'path': 'translator', 'tag_list': [], 'name_with_namespace': 'Kaiyin Zhong / translator', 'description': 'Translate text using google translate'}
# {'id': 8875151, '_id': ObjectId('5bc4bb4af0537b1328476310'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:Muskito/test2.git', 'http_url_to_repo': 'https://gitlab.com/Muskito/test2.git', 'created_at': '2018-10-15T16:02:04.035Z', 'web_url': 'https://gitlab.com/Muskito/test2', 'name': 'test2', 'namespace': {'id': 3808491, 'kind': 'user', 'parent_id': None, 'path': 'Muskito', 'full_path': 'Muskito', 'name': 'Muskito'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': None, 'path_with_namespace': 'Muskito/test2', 'last_activity_at': '2018-10-15T16:02:04.035Z', 'forks_count': 0, 'path': 'test2', 'tag_list': [], 'name_with_namespace': 'Elon / test2', 'description': ''}
# {'id': 8875114, '_id': ObjectId('5bc4bb4af0537b1328476311'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:daoshi/talks.git', 'http_url_to_repo': 'https://gitlab.com/daoshi/talks.git', 'created_at': '2018-10-15T15:59:33.965Z', 'web_url': 'https://gitlab.com/daoshi/talks', 'name': 'talks', 'namespace': {'id': 1344674, 'kind': 'user', 'parent_id': None, 'path': 'daoshi', 'full_path': 'daoshi', 'name': 'daoshi'}, 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8875114/puhpuhpuhpodium.png', 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/daoshi/talks/blob/master/README.rst', 'default_branch': 'master', 'path_with_namespace': 'daoshi/talks', 'last_activity_at': '2018-10-15T15:59:33.965Z', 'forks_count': 0, 'path': 'talks', 'tag_list': [], 'name_with_namespace': 'Daoshi / talks', 'description': 'Talks from dc562 members'}
# {'id': 8875083, '_id': ObjectId('5bc4bb4af0537b1328476312'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:jinxing_thpx/thpx_blog.git', 'http_url_to_repo': 'https://gitlab.com/jinxing_thpx/thpx_blog.git', 'created_at': '2018-10-15T15:57:49.232Z', 'web_url': 'https://gitlab.com/jinxing_thpx/thpx_blog', 'name': 'thpx_blog', 'namespace': {'id': 3810904, 'kind': 'user', 'parent_id': None, 'path': 'jinxing_thpx', 'full_path': 'jinxing_thpx', 'name': 'jinxing_thpx'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': None, 'path_with_namespace': 'jinxing_thpx/thpx_blog', 'last_activity_at': '2018-10-15T15:57:49.232Z', 'forks_count': 0, 'path': 'thpx_blog', 'tag_list': [], 'name_with_namespace': 'Jin Leng / thpx_blog', 'description': ''}
# {'id': 8875055, '_id': ObjectId('5bc4bb4af0537b1328476313'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:tidaporn/test2.git', 'http_url_to_repo': 'https://gitlab.com/tidaporn/test2.git', 'created_at': '2018-10-15T15:55:40.570Z', 'web_url': 'https://gitlab.com/tidaporn/test2', 'name': 'test2', 'namespace': {'id': 3426811, 'kind': 'user', 'parent_id': None, 'path': 'tidaporn', 'full_path': 'tidaporn', 'name': 'tidaporn'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': None, 'path_with_namespace': 'tidaporn/test2', 'last_activity_at': '2018-10-15T15:55:40.570Z', 'forks_count': 0, 'path': 'test2', 'tag_list': [], 'name_with_namespace': 'tidaporn / test2', 'description': ''}
# {'id': 8875042, '_id': ObjectId('5bc4bb4bf0537b1328476314'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:tidaporn/test.git', 'http_url_to_repo': 'https://gitlab.com/tidaporn/test.git', 'created_at': '2018-10-15T15:54:52.152Z', 'web_url': 'https://gitlab.com/tidaporn/test', 'name': 'test', 'namespace': {'id': 3426811, 'kind': 'user', 'parent_id': None, 'path': 'tidaporn', 'full_path': 'tidaporn', 'name': 'tidaporn'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/tidaporn/test/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'tidaporn/test', 'last_activity_at': '2018-10-15T15:54:52.152Z', 'forks_count': 0, 'path': 'test', 'tag_list': [], 'name_with_namespace': 'tidaporn / test', 'description': ''}
# {'id': 8875035, '_id': ObjectId('5bc4bb4bf0537b1328476315'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:nagayev/testci.git', 'http_url_to_repo': 'https://gitlab.com/nagayev/testci.git', 'created_at': '2018-10-15T15:54:27.797Z', 'web_url': 'https://gitlab.com/nagayev/testci', 'name': 'testci', 'namespace': {'id': 1476045, 'kind': 'user', 'parent_id': None, 'path': 'nagayev', 'full_path': 'nagayev', 'name': 'nagayev'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'nagayev/testci', 'last_activity_at': '2018-10-15T15:54:27.797Z', 'forks_count': 0, 'path': 'testci', 'tag_list': [], 'name_with_namespace': 'Marat / testci', 'description': 'Test Github CI'}
# ...
# {'id': 8873353, '_id': ObjectId('5bc4bc7af0537b1328476393'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:siddhata_aspl/total-sms-clone.git', 'http_url_to_repo': 'https://gitlab.com/siddhata_aspl/total-sms-clone.git', 'created_at': '2018-10-15T14:27:44.817Z', 'web_url': 'https://gitlab.com/siddhata_aspl/total-sms-clone', 'name': 'Total SMS Clone', 'namespace': {'id': 2653030, 'kind': 'user', 'parent_id': None, 'path': 'siddhata_aspl', 'full_path': 'siddhata_aspl', 'name': 'siddhata_aspl'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': None, 'path_with_namespace': 'siddhata_aspl/total-sms-clone', 'last_activity_at': '2018-10-15T14:27:44.817Z', 'forks_count': 0, 'path': 'total-sms-clone', 'tag_list': [], 'name_with_namespace': 'siddhata / Total SMS Clone', 'description': ''}
# {'id': 8873225, '_id': ObjectId('5bc4bc7bf0537b1328476394'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:misc0x10/test-repo.git', 'http_url_to_repo': 'https://gitlab.com/misc0x10/test-repo.git', 'created_at': '2018-10-15T14:20:22.372Z', 'web_url': 'https://gitlab.com/misc0x10/test-repo', 'name': 'Test-Repo', 'namespace': {'id': 3768847, 'kind': 'user', 'parent_id': None, 'path': 'misc0x10', 'full_path': 'misc0x10', 'name': 'misc0x10'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/misc0x10/test-repo/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'misc0x10/test-repo', 'last_activity_at': '2018-10-15T14:20:22.372Z', 'forks_count': 0, 'path': 'test-repo', 'tag_list': [], 'name_with_namespace': 'misc0x10 / Test-Repo', 'description': ''}
# {'id': 8873144, '_id': ObjectId('5bc4bc7ff0537b1328476395'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:meltano/target-csv.git', 'http_url_to_repo': 'https://gitlab.com/meltano/target-csv.git', 'created_at': '2018-10-15T14:16:55.084Z', 'web_url': 'https://gitlab.com/meltano/target-csv', 'name': 'target-csv', 'namespace': {'id': 2524164, 'kind': 'group', 'parent_id': None, 'path': 'meltano', 'full_path': 'meltano', 'name': 'meltano'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/meltano/target-csv/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'meltano/target-csv', 'last_activity_at': '2018-10-15T14:16:55.084Z', 'forks_count': 0, 'path': 'target-csv', 'tag_list': [], 'name_with_namespace': 'meltano / target-csv', 'description': ''}
# {'id': 8873052, '_id': ObjectId('5bc4bc7ff0537b1328476396'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:ahmed.elbarbri33/taxi_degla.git', 'http_url_to_repo': 'https://gitlab.com/ahmed.elbarbri33/taxi_degla.git', 'created_at': '2018-10-15T14:14:02.812Z', 'web_url': 'https://gitlab.com/ahmed.elbarbri33/taxi_degla', 'name': 'Taxi_Degla', 'namespace': {'id': 3760595, 'kind': 'user', 'parent_id': None, 'path': 'ahmed.elbarbri33', 'full_path': 'ahmed.elbarbri33', 'name': 'ahmed.elbarbri33'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'ahmed.elbarbri33/taxi_degla', 'last_activity_at': '2018-10-15T14:14:02.812Z', 'forks_count': 0, 'path': 'taxi_degla', 'tag_list': [], 'name_with_namespace': 'Ahmed EL-barbri / Taxi_Degla', 'description': ''}
# {'id': 8872966, '_id': ObjectId('5bc4bc80f0537b1328476397'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:ROUKIEN/tictrack.git', 'http_url_to_repo': 'https://gitlab.com/ROUKIEN/tictrack.git', 'created_at': '2018-10-15T14:11:24.304Z', 'web_url': 'https://gitlab.com/ROUKIEN/tictrack', 'name': 'tictrack', 'namespace': {'id': 907499, 'kind': 'user', 'parent_id': None, 'path': 'ROUKIEN', 'full_path': 'ROUKIEN', 'name': 'ROUKIEN'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/ROUKIEN/tictrack/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'ROUKIEN/tictrack', 'last_activity_at': '2018-10-15T14:11:24.304Z', 'forks_count': 0, 'path': 'tictrack', 'tag_list': [], 'name_with_namespace': 'Rukien / tictrack', 'description': 'Track your topics speaking time during your meetings'}
# {'id': 8872858, '_id': ObjectId('5bc4bc80f0537b1328476398'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:dewey-dot/terrain.git', 'http_url_to_repo': 'https://gitlab.com/dewey-dot/terrain.git', 'created_at': '2018-10-15T14:07:26.322Z', 'web_url': 'https://gitlab.com/dewey-dot/terrain', 'name': 'terrain', 'namespace': {'id': 3609329, 'kind': 'group', 'parent_id': None, 'path': 'dewey-dot', 'full_path': 'dewey-dot', 'name': ' The Dewey-Dot Foundation. '}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': None, 'path_with_namespace': 'dewey-dot/terrain', 'last_activity_at': '2018-10-15T14:07:26.322Z', 'forks_count': 0, 'path': 'terrain', 'tag_list': [], 'name_with_namespace': ' The Dewey-Dot Foundation.  / terrain', 'description': '(Weak Pun On Train) Collection Of Mods & An Associated Game-Mode For Terasology To Build Up Some Basic Programming & Electronics Skills; Eventually Want To Plan A MOOC Around This.\r\n'}
# {'id': 8872796, '_id': ObjectId('5bc4bc85f0537b1328476399'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:A_FLOOD/task1.git', 'http_url_to_repo': 'https://gitlab.com/A_FLOOD/task1.git', 'created_at': '2018-10-15T14:04:48.133Z', 'web_url': 'https://gitlab.com/A_FLOOD/task1', 'name': 'task1', 'namespace': {'id': 3083573, 'kind': 'user', 'parent_id': None, 'path': 'A_FLOOD', 'full_path': 'A_FLOOD', 'name': 'A_FLOOD'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': None, 'path_with_namespace': 'A_FLOOD/task1', 'last_activity_at': '2018-10-15T14:04:48.133Z', 'forks_count': 0, 'path': 'task1', 'tag_list': [], 'name_with_namespace': 'Alexander / task1', 'description': ''}
# {'id': 8871892, '_id': ObjectId('5bc4bc8ff0537b132847639a'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:usernameddd/test.git', 'http_url_to_repo': 'https://gitlab.com/usernameddd/test.git', 'created_at': '2018-10-15T13:18:49.732Z', 'web_url': 'https://gitlab.com/usernameddd/test', 'name': 'test', 'namespace': {'id': 3809612, 'kind': 'user', 'parent_id': None, 'path': 'usernameddd', 'full_path': 'usernameddd', 'name': 'usernameddd'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': None, 'path_with_namespace': 'usernameddd/test', 'last_activity_at': '2018-10-15T13:18:49.732Z', 'forks_count': 0, 'path': 'test', 'tag_list': [], 'name_with_namespace': 'usernameddd / test', 'description': '测试项目'}
# {'id': 8871683, '_id': ObjectId('5bc4bc8ff0537b132847639b'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:gerald.duveau/transactional-email-templates.git', 'http_url_to_repo': 'https://gitlab.com/gerald.duveau/transactional-email-templates.git', 'created_at': '2018-10-15T13:07:33.021Z', 'web_url': 'https://gitlab.com/gerald.duveau/transactional-email-templates', 'name': 'transactional-email-templates', 'namespace': {'id': 3808577, 'kind': 'user', 'parent_id': None, 'path': 'gerald.duveau', 'full_path': 'gerald.duveau', 'name': 'gerald.duveau'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/gerald.duveau/transactional-email-templates/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'gerald.duveau/transactional-email-templates', 'last_activity_at': '2018-10-15T13:07:33.021Z', 'forks_count': 0, 'path': 'transactional-email-templates', 'tag_list': [], 'name_with_namespace': 'gérald / transactional-email-templates', 'description': 'Responsive transactional HTML email templates'}
# {'id': 8871583, '_id': ObjectId('5bc4bc90f0537b132847639c'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:QuantumDE/TrytonModules/timesheet.git', 'http_url_to_repo': 'https://gitlab.com/QuantumDE/TrytonModules/timesheet.git', 'created_at': '2018-10-15T13:01:56.179Z', 'web_url': 'https://gitlab.com/QuantumDE/TrytonModules/timesheet', 'name': 'timesheet', 'namespace': {'id': 3809505, 'kind': 'group', 'parent_id': 3014886, 'path': 'TrytonModules', 'full_path': 'QuantumDE/TrytonModules', 'name': 'TrytonModules'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/QuantumDE/TrytonModules/timesheet/blob/develop/README', 'default_branch': 'develop', 'path_with_namespace': 'QuantumDE/TrytonModules/timesheet', 'last_activity_at': '2018-10-15T13:01:56.179Z', 'forks_count': 0, 'path': 'timesheet', 'tag_list': [], 'name_with_namespace': 'QuantumDE / TrytonModules / timesheet', 'description': 'timesheet module'}
# {'id': 8871561, '_id': ObjectId('5bc4bc90f0537b132847639d'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:QuantumDE/TrytonModules/timesheet_cost.git', 'http_url_to_repo': 'https://gitlab.com/QuantumDE/TrytonModules/timesheet_cost.git', 'created_at': '2018-10-15T13:00:39.050Z', 'web_url': 'https://gitlab.com/QuantumDE/TrytonModules/timesheet_cost', 'name': 'timesheet_cost', 'namespace': {'id': 3809505, 'kind': 'group', 'parent_id': 3014886, 'path': 'TrytonModules', 'full_path': 'QuantumDE/TrytonModules', 'name': 'TrytonModules'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/QuantumDE/TrytonModules/timesheet_cost/blob/develop/README', 'default_branch': 'develop', 'path_with_namespace': 'QuantumDE/TrytonModules/timesheet_cost', 'last_activity_at': '2018-10-15T13:00:39.050Z', 'forks_count': 0, 'path': 'timesheet_cost', 'tag_list': [], 'name_with_namespace': 'QuantumDE / TrytonModules / timesheet_cost', 'description': 'timesheet cost module'}
# {'id': 8871427, '_id': ObjectId('5bc4bc95f0537b132847639e'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:krische/test.git', 'http_url_to_repo': 'https://gitlab.com/krische/test.git', 'created_at': '2018-10-15T12:51:19.027Z', 'web_url': 'https://gitlab.com/krische/test', 'name': 'test', 'namespace': {'id': 18682, 'kind': 'user', 'parent_id': None, 'path': 'krische', 'full_path': 'krische', 'name': 'krische'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/krische/test/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'krische/test', 'last_activity_at': '2018-10-15T12:51:19.027Z', 'forks_count': 0, 'path': 'test', 'tag_list': [], 'name_with_namespace': 'Brian Krische / test', 'description': ''}
# {'id': 8871084, '_id': ObjectId('5bc4bc9af0537b132847639f'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:BananaRay/tomat.git', 'http_url_to_repo': 'https://gitlab.com/BananaRay/tomat.git', 'created_at': '2018-10-15T12:33:19.702Z', 'web_url': 'https://gitlab.com/BananaRay/tomat', 'name': 'tomat', 'namespace': {'id': 3809353, 'kind': 'user', 'parent_id': None, 'path': 'BananaRay', 'full_path': 'BananaRay', 'name': 'BananaRay'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'BananaRay/tomat', 'last_activity_at': '2018-10-15T13:33:34.765Z', 'forks_count': 0, 'path': 'tomat', 'tag_list': [], 'name_with_namespace': 'Evgeniy Gorokhov / tomat', 'description': ''}
# {'id': 8870942, '_id': ObjectId('5bc4bc9af0537b13284763a0'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:PatrickUMH/tarea9.git', 'http_url_to_repo': 'https://gitlab.com/PatrickUMH/tarea9.git', 'created_at': '2018-10-15T12:28:54.678Z', 'web_url': 'https://gitlab.com/PatrickUMH/tarea9', 'name': 'Tarea9', 'namespace': {'id': 3358190, 'kind': 'user', 'parent_id': None, 'path': 'PatrickUMH', 'full_path': 'PatrickUMH', 'name': 'PatrickUMH'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'PatrickUMH/tarea9', 'last_activity_at': '2018-10-15T12:28:54.678Z', 'forks_count': 0, 'path': 'tarea9', 'tag_list': [], 'name_with_namespace': 'Patrick Uriel Mendoza Hernández / Tarea9', 'description': ''}
# {'id': 8870488, '_id': ObjectId('5bc4bc9af0537b13284763a1'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:COchs/todo-app-experiments.git', 'http_url_to_repo': 'https://gitlab.com/COchs/todo-app-experiments.git', 'created_at': '2018-10-15T12:00:00.410Z', 'web_url': 'https://gitlab.com/COchs/todo-app-experiments', 'name': 'Todo App Experiments', 'namespace': {'id': 431484, 'kind': 'user', 'parent_id': None, 'path': 'COchs', 'full_path': 'COchs', 'name': 'COchs'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'COchs/todo-app-experiments', 'last_activity_at': '2018-10-15T12:00:00.410Z', 'forks_count': 0, 'path': 'todo-app-experiments', 'tag_list': [], 'name_with_namespace': 'Christopher Ochs / Todo App Experiments', 'description': ''}
# {'id': 8869765, '_id': ObjectId('5bc4bca4f0537b13284763a2'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:anisch01/testgit.git', 'http_url_to_repo': 'https://gitlab.com/anisch01/testgit.git', 'created_at': '2018-10-15T11:18:30.854Z', 'web_url': 'https://gitlab.com/anisch01/testgit', 'name': 'testgit', 'namespace': {'id': 3807888, 'kind': 'user', 'parent_id': None, 'path': 'anisch01', 'full_path': 'anisch01', 'name': 'anisch01'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'anisch01/testgit', 'last_activity_at': '2018-10-15T11:18:30.854Z', 'forks_count': 0, 'path': 'testgit', 'tag_list': [], 'name_with_namespace': 'Anis chourasia / testgit', 'description': ''}
# {'id': 8868758, '_id': ObjectId('5bc4bcb2f0537b13284763a3'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:myontars/TelveTroll.git', 'http_url_to_repo': 'https://gitlab.com/myontars/TelveTroll.git', 'created_at': '2018-10-15T10:27:55.985Z', 'web_url': 'https://gitlab.com/myontars/TelveTroll', 'name': 'TelveTroll', 'namespace': {'id': 1845377, 'kind': 'user', 'parent_id': None, 'path': 'myontars', 'full_path': 'myontars', 'name': 'myontars'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': 'https://gitlab.com/myontars/TelveTroll/blob/master/README.md', 'default_branch': 'master', 'path_with_namespace': 'myontars/TelveTroll', 'last_activity_at': '2018-10-15T10:27:55.985Z', 'forks_count': 0, 'path': 'TelveTroll', 'tag_list': [], 'name_with_namespace': 'Mustafa / TelveTroll', 'description': None}
# {'id': 8868696, '_id': ObjectId('5bc4bcb2f0537b13284763a4'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:karanrajpal14/trydjango19.git', 'http_url_to_repo': 'https://gitlab.com/karanrajpal14/trydjango19.git', 'created_at': '2018-10-15T10:23:26.483Z', 'web_url': 'https://gitlab.com/karanrajpal14/trydjango19', 'name': 'trydjango19', 'namespace': {'id': 289074, 'kind': 'user', 'parent_id': None, 'path': 'karanrajpal14', 'full_path': 'karanrajpal14', 'name': 'karanrajpal14'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'karanrajpal14/trydjango19', 'last_activity_at': '2018-10-15T10:23:26.483Z', 'forks_count': 0, 'path': 'trydjango19', 'tag_list': [], 'name_with_namespace': 'Karan Rajpal / trydjango19', 'description': 'A demo Django blog developed for learning purposes using https://www.youtube.com/playlist?list=PLEsfXFp6DpzQFqfCur9CJ4QnKQTVXUsRy'}
# {'id': 8868066, '_id': ObjectId('5bc4bcb3f0537b13284763a5'), 'star_count': 0, 'ssh_url_to_repo': 'git@gitlab.com:sunitaku/training_sdet.git', 'http_url_to_repo': 'https://gitlab.com/sunitaku/training_sdet.git', 'created_at': '2018-10-15T09:46:15.277Z', 'web_url': 'https://gitlab.com/sunitaku/training_sdet', 'name': 'Training_SDET', 'namespace': {'id': 3776640, 'kind': 'user', 'parent_id': None, 'path': 'sunitaku', 'full_path': 'sunitaku', 'name': 'sunitaku'}, 'avatar_url': None, 'forge': 'gitlab', 'readme_url': None, 'default_branch': 'master', 'path_with_namespace': 'sunitaku/training_sdet', 'last_activity_at': '2018-10-15T13:04:53.094Z', 'forks_count': 0, 'path': 'training_sdet', 'tag_list': [], 'name_with_namespace': 'Sunita Kumari / Training_SDET', 'description': ''}
