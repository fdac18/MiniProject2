# %%
import sys
import re
import pymongo
import json
import time
import datetime
import requests
from bs4 import BeautifulSoup

dbname = "fdac18mp2" #please use this database
collname = "glprj_jdong6" #please modify so you store data in your collection
my_char = 'q'

# beginning page index
begin = "230"
client = pymongo.MongoClient()

db = client[dbname]
coll = db[collname]


gitlab_url = "https://gitlab.com/api/v4/projects?archived=false&membership=false&order_by=created_at&owned=false&page=" + begin + \
    "&per_page=99&simple=false&sort=desc&starred=false&statistics=false&with_custom_attributes=false&with_issues_enabled=false&with_merge_requests_enabled=false"

gleft = 20

source_url = "https://sourceforge.net/directory/?q=" + my_char + "&sort=name&page="
rest_url = "https://sourceforge.net/rest/p/"

header = {'per_page': 99}

# check remaining query chances for rate-limit restriction
def wait(left):
    global header
    while (left < 20):
        l = requests.get('https://gitlab.com/api/v4/projects', headers=header)
        if (l.ok):
            left = int(l.headers.get('RateLimit-Remaining'))
        time .sleep(60)
    return left

def project_exists(url):
    r = requests.get(url)
    if r.status_code == 200:
        return True
    return False

def get_source(url, coll, rest):
    page = 1
    project_count = 0
    while True:
        resp = requests.get(url + str(page))
        text = resp.text
        soup = BeautifulSoup(text, 'html.parser')
        if re.search('No results found.', soup.get_text()):
            return

        for link in soup.find_all(class_="project-icon", href=True):
            name = re.findall('/projects/([A-Za-z0-9\-]*)', link.get('href'))
            name = name[0] if name else None
            if name is not None and name.lower().startswith(my_char):
                resp = requests.get(rest + name)
                if resp.status_code == 200:
                    info = json.loads(resp.text)
                    info['forge'] = 'sourceforge'
                    coll.insert_one(info)
                    project_count += 1
                    if project_count >= 50:
                        return
        page += 1
    return

# send queries and extract urls 
def get_gitlab(url, coll):

    global gleft
    global header
    global bginnum
    gleft = wait(gleft)
    values = []
    size = 0
    project_count = 0

    try:
        r = requests .get(url, headers=header)
        time .sleep(0.5)
        # got blocked
        if r.status_code == 403:
            return "got blocked", str(bginnum)
        if (r.ok):

            gleft = int(r.headers.get('RateLimit-Remaining'))
            lll = r.headers.get('Link')
            t = r.text
            array = json.loads(t)
            
            for el in array:
                if el['name'].lower().startswith(my_char):
                    if project_exists(el['http_url_to_repo']):
                        project_count += 1
                        el['forge'] = 'gitlab'
                        coll.insert_one(el)
                        if project_count >= 50:
                            return
            
            #next page
            while ('; rel="next"' in lll):
                gleft = int(r.headers.get('RateLimit-Remaining'))
                gleft = wait(gleft)
                # extract next page url
                ll = lll.replace(';', ',').split(',')
                url = ll[ll.index(' rel="next"') -
                         1].replace('<', '').replace('>', '').lstrip()
             
                try:
                    r = requests .get(url, headers=header)
                    if r.status_code == 403:
                        return "got blocked", str(bginnum)
                    if (r.ok):
                        lll = r.headers.get('Link')
                        t = r.text
                        array1 = json.loads(t)
                        for el in array1:
                            if el['name'].lower().startswith(my_char):
                                if project_exists(el['http_url_to_repo']):
                                    project_count += 1
                                    el['forge'] = 'gitlab'
                                    coll.insert_one(el)
                                    if project_count >= 50:
                                        return
                    else:
                        sys.stderr.write("url can not found:\n" + url + '\n')
                        return 
                except requests.exceptions.ConnectionError:
                    sys.stderr.write('could not get ' + url + '\n')
            
        else:
            sys.stderr.write("url can not found:\n" + url + '\n')
            return

    except requests.exceptions.ConnectionError:
        sys.stderr.write('could not get ' + url + '\n')
    except Exception as e:
        sys.stderr.write(url + ';' + str(e) + '\n')
        
#start retrieving        
get_gitlab(gitlab_url,coll)
get_source(source_url, coll, rest_url)
#print collected data
for doc in coll.find({}):
    print(doc)
# Out:
# {'namespace': {'parent_id': None, 'name': 'pkyisky', 'id': 2574518, 'full_path': 'pkyisky', 'path': 'pkyisky', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-05T03:31:36.917Z', 'name': 'qrcodeScanner', 'http_url_to_repo': 'https://gitlab.com/pkyisky/qrcodeScanner.git', 'readme_url': None, 'last_activity_at': '2018-10-05T03:31:36.917Z', 'path': 'qrcodeScanner', 'ssh_url_to_repo': 'git@gitlab.com:pkyisky/qrcodeScanner.git', 'star_count': 0, '_id': ObjectId('5bc4f111856cc60875672498'), 'name_with_namespace': 'Pradeep Yadav / qrcodeScanner', 'web_url': 'https://gitlab.com/pkyisky/qrcodeScanner', 'avatar_url': None, 'path_with_namespace': 'pkyisky/qrcodeScanner', 'id': 8709376, 'forks_count': 0, 'description': None, 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'pkyisky', 'id': 2574518, 'full_path': 'pkyisky', 'path': 'pkyisky', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-05T03:31:35.295Z', 'name': 'qimage2ndarray', 'http_url_to_repo': 'https://gitlab.com/pkyisky/qimage2ndarray.git', 'readme_url': 'https://gitlab.com/pkyisky/qimage2ndarray/blob/master/README.rst', 'last_activity_at': '2018-10-05T03:31:35.295Z', 'path': 'qimage2ndarray', 'ssh_url_to_repo': 'git@gitlab.com:pkyisky/qimage2ndarray.git', 'star_count': 0, '_id': ObjectId('5bc4f112856cc60875672499'), 'name_with_namespace': 'Pradeep Yadav / qimage2ndarray', 'web_url': 'https://gitlab.com/pkyisky/qimage2ndarray', 'avatar_url': None, 'path_with_namespace': 'pkyisky/qimage2ndarray', 'id': 8709374, 'forks_count': 0, 'description': 'qimage2ndarray is a small python extension for quickly converting between QImages and numpy.ndarrays (in both directions).', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'iPwnOSX_', 'id': 3745073, 'full_path': 'iPwnOSX_', 'path': 'iPwnOSX_', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-05T01:32:22.109Z', 'name': 'qqbot', 'http_url_to_repo': 'https://gitlab.com/iPwnOSX_/qqbot.git', 'readme_url': 'https://gitlab.com/iPwnOSX_/qqbot/blob/master/README.md', 'last_activity_at': '2018-10-05T01:32:22.109Z', 'path': 'qqbot', 'ssh_url_to_repo': 'git@gitlab.com:iPwnOSX_/qqbot.git', 'star_count': 0, '_id': ObjectId('5bc4f117856cc6087567249a'), 'name_with_namespace': 'Taylor Traxx / qqbot', 'web_url': 'https://gitlab.com/iPwnOSX_/qqbot', 'avatar_url': None, 'path_with_namespace': 'iPwnOSX_/qqbot', 'id': 8708284, 'forks_count': 0, 'description': ':fire: SmartQQ Robot and API Server, powered by node.js', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'marcusmourao', 'id': 1679805, 'full_path': 'marcusmourao', 'path': 'marcusmourao', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T23:18:40.133Z', 'name': 'quickstart-android', 'http_url_to_repo': 'https://gitlab.com/marcusmourao/quickstart-android.git', 'readme_url': 'https://gitlab.com/marcusmourao/quickstart-android/blob/master/README.md', 'last_activity_at': '2018-10-04T23:18:40.133Z', 'path': 'quickstart-android', 'ssh_url_to_repo': 'git@gitlab.com:marcusmourao/quickstart-android.git', 'star_count': 0, '_id': ObjectId('5bc4f120856cc6087567249b'), 'name_with_namespace': 'Marcus Mourão / quickstart-android', 'web_url': 'https://gitlab.com/marcusmourao/quickstart-android', 'avatar_url': None, 'path_with_namespace': 'marcusmourao/quickstart-android', 'id': 8707346, 'forks_count': 0, 'description': 'Firebase Quickstart Samples for Android', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'Asharas', 'id': 3240685, 'full_path': 'Asharas', 'path': 'Asharas', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T20:46:59.695Z', 'name': 'QD_nmap', 'http_url_to_repo': 'https://gitlab.com/Asharas/QD_nmap.git', 'readme_url': 'https://gitlab.com/Asharas/QD_nmap/blob/master/README.md', 'last_activity_at': '2018-10-04T20:46:59.695Z', 'path': 'QD_nmap', 'ssh_url_to_repo': 'git@gitlab.com:Asharas/QD_nmap.git', 'star_count': 0, '_id': ObjectId('5bc4f126856cc6087567249c'), 'name_with_namespace': 'Philippe V / QD_nmap', 'web_url': 'https://gitlab.com/Asharas/QD_nmap', 'avatar_url': None, 'path_with_namespace': 'Asharas/QD_nmap', 'id': 8706094, 'forks_count': 0, 'description': "Quick 'n Dirty nmap docker", 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'xacrimon', 'id': 1693225, 'full_path': 'xacrimon', 'path': 'xacrimon', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T19:01:08.263Z', 'name': 'qsh', 'http_url_to_repo': 'https://gitlab.com/xacrimon/qsh.git', 'readme_url': 'https://gitlab.com/xacrimon/qsh/blob/master/README.md', 'last_activity_at': '2018-10-15T18:47:36.321Z', 'path': 'qsh', 'ssh_url_to_repo': 'git@gitlab.com:xacrimon/qsh.git', 'star_count': 1, '_id': ObjectId('5bc4f12f856cc6087567249d'), 'name_with_namespace': 'Acrimon / qsh', 'web_url': 'https://gitlab.com/xacrimon/qsh', 'avatar_url': None, 'path_with_namespace': 'xacrimon/qsh', 'id': 8704855, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'Andreynnt', 'id': 3743669, 'full_path': 'Andreynnt', 'path': 'Andreynnt', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T17:58:34.034Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/Andreynnt/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-05T19:58:44.477Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:Andreynnt/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f134856cc6087567249e'), 'name_with_namespace': 'Andrey Babkov / qa', 'web_url': 'https://gitlab.com/Andreynnt/unit-testing', 'avatar_url': None, 'path_with_namespace': 'Andreynnt/unit-testing', 'id': 8703983, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'Starflow', 'id': 3743122, 'full_path': 'Starflow', 'path': 'Starflow', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T16:28:20.169Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/Starflow/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-09T11:49:52.242Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:Starflow/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f13a856cc6087567249f'), 'name_with_namespace': 'Britikov Konstantin / qa', 'web_url': 'https://gitlab.com/Starflow/unit-testing', 'avatar_url': None, 'path_with_namespace': 'Starflow/unit-testing', 'id': 8702825, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'Thewhiterabbit123', 'id': 2499366, 'full_path': 'Thewhiterabbit123', 'path': 'Thewhiterabbit123', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T16:27:35.334Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/Thewhiterabbit123/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-04T17:52:47.881Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:Thewhiterabbit123/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f13a856cc608756724a0'), 'name_with_namespace': 'Vasilieva Nadia / qa', 'web_url': 'https://gitlab.com/Thewhiterabbit123/unit-testing', 'avatar_url': None, 'path_with_namespace': 'Thewhiterabbit123/unit-testing', 'id': 8702813, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'iminchenko', 'id': 1931971, 'full_path': 'iminchenko', 'path': 'iminchenko', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T16:24:28.908Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/iminchenko/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-04T16:24:28.908Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:iminchenko/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f13a856cc608756724a1'), 'name_with_namespace': 'Ilia / qa', 'web_url': 'https://gitlab.com/iminchenko/unit-testing', 'avatar_url': None, 'path_with_namespace': 'iminchenko/unit-testing', 'id': 8702768, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'supreme2302', 'id': 3743123, 'full_path': 'supreme2302', 'path': 'supreme2302', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T16:23:54.591Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/supreme2302/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-04T22:15:12.569Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:supreme2302/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f13a856cc608756724a2'), 'name_with_namespace': 'Egor Chuvashov / qa', 'web_url': 'https://gitlab.com/supreme2302/unit-testing', 'avatar_url': None, 'path_with_namespace': 'supreme2302/unit-testing', 'id': 8702764, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'Dmitryks', 'id': 2514763, 'full_path': 'Dmitryks', 'path': 'Dmitryks', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T16:23:25.520Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/Dmitryks/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-04T16:23:25.520Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:Dmitryks/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f13b856cc608756724a3'), 'name_with_namespace': 'Dmitry / qa', 'web_url': 'https://gitlab.com/Dmitryks/unit-testing', 'avatar_url': None, 'path_with_namespace': 'Dmitryks/unit-testing', 'id': 8702760, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'oshkina95', 'id': 3743118, 'full_path': 'oshkina95', 'path': 'oshkina95', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T16:22:39.414Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/oshkina95/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-04T16:22:39.414Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:oshkina95/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f13b856cc608756724a4'), 'name_with_namespace': 'Elena Oshkina / qa', 'web_url': 'https://gitlab.com/oshkina95/unit-testing', 'avatar_url': None, 'path_with_namespace': 'oshkina95/unit-testing', 'id': 8702748, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'puchninanastya', 'id': 3743110, 'full_path': 'puchninanastya', 'path': 'puchninanastya', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T16:22:27.219Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/puchninanastya/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-04T16:22:27.219Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:puchninanastya/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f13b856cc608756724a5'), 'name_with_namespace': 'Anastasia Puchnina / qa', 'web_url': 'https://gitlab.com/puchninanastya/unit-testing', 'avatar_url': None, 'path_with_namespace': 'puchninanastya/unit-testing', 'id': 8702744, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'HimmelSpark', 'id': 2024955, 'full_path': 'HimmelSpark', 'path': 'HimmelSpark', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T16:22:12.814Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/HimmelSpark/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-11T21:11:24.549Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:HimmelSpark/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f13c856cc608756724a6'), 'name_with_namespace': 'HimmelSpark / qa', 'web_url': 'https://gitlab.com/HimmelSpark/unit-testing', 'avatar_url': None, 'path_with_namespace': 'HimmelSpark/unit-testing', 'id': 8702741, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'InfantryMan', 'id': 3743109, 'full_path': 'InfantryMan', 'path': 'InfantryMan', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T16:22:09.096Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/InfantryMan/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-04T16:22:09.096Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:InfantryMan/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f13d856cc608756724a7'), 'name_with_namespace': 'Rustam Migranov / qa', 'web_url': 'https://gitlab.com/InfantryMan/unit-testing', 'avatar_url': None, 'path_with_namespace': 'InfantryMan/unit-testing', 'id': 8702740, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'Rukid', 'id': 3743107, 'full_path': 'Rukid', 'path': 'Rukid', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T16:21:45.021Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/Rukid/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-15T10:36:56.663Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:Rukid/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f13d856cc608756724a8'), 'name_with_namespace': 'Ivan Nemshilov / qa', 'web_url': 'https://gitlab.com/Rukid/unit-testing', 'avatar_url': None, 'path_with_namespace': 'Rukid/unit-testing', 'id': 8702734, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'k.kucherov', 'id': 872090, 'full_path': 'k.kucherov', 'path': 'k.kucherov', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T16:21:29.005Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/k.kucherov/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-04T20:07:05.271Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:k.kucherov/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f13d856cc608756724a9'), 'name_with_namespace': 'Kirill Kucherov / qa', 'web_url': 'https://gitlab.com/k.kucherov/unit-testing', 'avatar_url': None, 'path_with_namespace': 'k.kucherov/unit-testing', 'id': 8702732, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'VictoriaOtm', 'id': 3743106, 'full_path': 'VictoriaOtm', 'path': 'VictoriaOtm', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T16:21:28.186Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/VictoriaOtm/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-04T16:21:28.186Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:VictoriaOtm/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f13e856cc608756724aa'), 'name_with_namespace': 'Victoria / qa', 'web_url': 'https://gitlab.com/VictoriaOtm/unit-testing', 'avatar_url': None, 'path_with_namespace': 'VictoriaOtm/unit-testing', 'id': 8702731, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'renataclover', 'id': 2570833, 'full_path': 'renataclover', 'path': 'renataclover', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T16:11:31.496Z', 'name': 'qa', 'http_url_to_repo': 'https://gitlab.com/renataclover/unit-testing.git', 'readme_url': None, 'last_activity_at': '2018-10-15T10:41:16.126Z', 'path': 'unit-testing', 'ssh_url_to_repo': 'git@gitlab.com:renataclover/unit-testing.git', 'star_count': 0, '_id': ObjectId('5bc4f142856cc608756724ab'), 'name_with_namespace': 'Renata Minigalieva / qa', 'web_url': 'https://gitlab.com/renataclover/unit-testing', 'avatar_url': None, 'path_with_namespace': 'renataclover/unit-testing', 'id': 8702585, 'forks_count': 15, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'cyril.vignet', 'id': 3742799, 'full_path': 'cyril.vignet', 'path': 'cyril.vignet', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T15:39:41.301Z', 'name': 'QAXH', 'http_url_to_repo': 'https://gitlab.com/cyril.vignet/QAXH.git', 'readme_url': 'https://gitlab.com/cyril.vignet/QAXH/blob/master/README.md', 'last_activity_at': '2018-10-05T09:13:31.467Z', 'path': 'QAXH', 'ssh_url_to_repo': 'git@gitlab.com:cyril.vignet/QAXH.git', 'star_count': 0, '_id': ObjectId('5bc4f143856cc608756724ac'), 'name_with_namespace': 'Cyril Vignet / QAXH', 'web_url': 'https://gitlab.com/cyril.vignet/QAXH', 'avatar_url': None, 'path_with_namespace': 'cyril.vignet/QAXH', 'id': 8702124, 'forks_count': 0, 'description': None, 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'lgandelin', 'id': 185153, 'full_path': 'lgandelin', 'path': 'lgandelin', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T15:02:20.751Z', 'name': 'quik-tech-test', 'http_url_to_repo': 'https://gitlab.com/lgandelin/quik-tech-test.git', 'readme_url': 'https://gitlab.com/lgandelin/quik-tech-test/blob/dev/readme.md', 'last_activity_at': '2018-10-04T15:02:20.751Z', 'path': 'quik-tech-test', 'ssh_url_to_repo': 'git@gitlab.com:lgandelin/quik-tech-test.git', 'star_count': 0, '_id': ObjectId('5bc4f147856cc608756724ad'), 'name_with_namespace': 'Louis Gandelin / quik-tech-test', 'web_url': 'https://gitlab.com/lgandelin/quik-tech-test', 'avatar_url': None, 'path_with_namespace': 'lgandelin/quik-tech-test', 'id': 8701536, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'dev'}
# {'namespace': {'parent_id': None, 'name': 'quetzal77', 'id': 3741784, 'full_path': 'quetzal77', 'path': 'quetzal77', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T14:48:33.296Z', 'name': 'quetzal-test', 'http_url_to_repo': 'https://gitlab.com/quetzal77/quetzal-test.git', 'readme_url': None, 'last_activity_at': '2018-10-05T09:48:52.995Z', 'path': 'quetzal-test', 'ssh_url_to_repo': 'git@gitlab.com:quetzal77/quetzal-test.git', 'star_count': 0, '_id': ObjectId('5bc4f147856cc608756724ae'), 'name_with_namespace': 'quetzal77 / quetzal-test', 'web_url': 'https://gitlab.com/quetzal77/quetzal-test', 'avatar_url': None, 'path_with_namespace': 'quetzal77/quetzal-test', 'id': 8701305, 'forks_count': 0, 'description': None, 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'quetzal77', 'id': 3741784, 'full_path': 'quetzal77', 'path': 'quetzal77', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T13:28:48.791Z', 'name': 'quetzal-trv', 'http_url_to_repo': 'https://gitlab.com/quetzal77/quetzal-trv.git', 'readme_url': None, 'last_activity_at': '2018-10-04T13:28:48.791Z', 'path': 'quetzal-trv', 'ssh_url_to_repo': 'git@gitlab.com:quetzal77/quetzal-trv.git', 'star_count': 0, '_id': ObjectId('5bc4f151856cc608756724af'), 'name_with_namespace': 'quetzal77 / quetzal-trv', 'web_url': 'https://gitlab.com/quetzal77/quetzal-trv', 'avatar_url': None, 'path_with_namespace': 'quetzal77/quetzal-trv', 'id': 8699789, 'forks_count': 0, 'description': None, 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'pr-', 'id': 3741553, 'full_path': 'pr-', 'path': 'pr-', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T12:54:24.435Z', 'name': 'qwert', 'http_url_to_repo': 'https://gitlab.com/pr-/qwert.git', 'readme_url': 'https://gitlab.com/pr-/qwert/blob/master/Readme.md', 'last_activity_at': '2018-10-04T12:54:24.435Z', 'path': 'qwert', 'ssh_url_to_repo': 'git@gitlab.com:pr-/qwert.git', 'star_count': 0, '_id': ObjectId('5bc4f156856cc608756724b0'), 'name_with_namespace': 'jocosipifo / qwert', 'web_url': 'https://gitlab.com/pr-/qwert', 'avatar_url': None, 'path_with_namespace': 'pr-/qwert', 'id': 8699223, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'fgoudreault', 'id': 666577, 'full_path': 'fgoudreault', 'path': 'fgoudreault', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T10:45:07.385Z', 'name': 'q-e', 'http_url_to_repo': 'https://gitlab.com/fgoudreault/q-e.git', 'readme_url': 'https://gitlab.com/fgoudreault/q-e/blob/develop/README.md', 'last_activity_at': '2018-10-04T10:45:07.385Z', 'path': 'q-e', 'ssh_url_to_repo': 'git@gitlab.com:fgoudreault/q-e.git', 'star_count': 0, '_id': ObjectId('5bc4f166856cc608756724b1'), 'name_with_namespace': 'fgoudreault / q-e', 'web_url': 'https://gitlab.com/fgoudreault/q-e', 'avatar_url': 'https://gitlab.com/fgoudreault/q-e/avatar', 'path_with_namespace': 'fgoudreault/q-e', 'id': 8697275, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'develop'}
# {'namespace': {'parent_id': None, 'name': 'ngonimapfumo', 'id': 1382467, 'full_path': 'ngonimapfumo', 'path': 'ngonimapfumo', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T09:50:22.947Z', 'name': 'questionnaire.py', 'http_url_to_repo': 'https://gitlab.com/ngonimapfumo/questionnaire.py.git', 'readme_url': 'https://gitlab.com/ngonimapfumo/questionnaire.py/blob/master/README.md', 'last_activity_at': '2018-10-04T09:50:22.947Z', 'path': 'questionnaire.py', 'ssh_url_to_repo': 'git@gitlab.com:ngonimapfumo/questionnaire.py.git', 'star_count': 0, '_id': ObjectId('5bc4f16a856cc608756724b2'), 'name_with_namespace': 'Ngoni Mapfumo / questionnaire.py', 'web_url': 'https://gitlab.com/ngonimapfumo/questionnaire.py', 'avatar_url': None, 'path_with_namespace': 'ngonimapfumo/questionnaire.py', 'id': 8696441, 'forks_count': 0, 'description': 'its a simple questionnaire', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'malo.inhon', 'id': 3739896, 'full_path': 'malo.inhon', 'path': 'malo.inhon', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T08:54:25.808Z', 'name': 'QF20170921', 'http_url_to_repo': 'https://gitlab.com/malo.inhon/QF20170921.git', 'readme_url': 'https://gitlab.com/malo.inhon/QF20170921/blob/master/README.md', 'last_activity_at': '2018-10-04T08:54:25.808Z', 'path': 'QF20170921', 'ssh_url_to_repo': 'git@gitlab.com:malo.inhon/QF20170921.git', 'star_count': 0, '_id': ObjectId('5bc4f178856cc608756724b3'), 'name_with_namespace': 'malo.inhon / QF20170921', 'web_url': 'https://gitlab.com/malo.inhon/QF20170921', 'avatar_url': None, 'path_with_namespace': 'malo.inhon/QF20170921', 'id': 8695446, 'forks_count': 0, 'description': '2017 金融投資與程式交易 (中山財管)', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'shaharia', 'id': 3736127, 'full_path': 'shaharia', 'path': 'shaharia', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T07:26:49.693Z', 'name': 'quill', 'http_url_to_repo': 'https://gitlab.com/shaharia/quill.git', 'readme_url': 'https://gitlab.com/shaharia/quill/blob/master/README.md', 'last_activity_at': '2018-10-04T07:26:49.693Z', 'path': 'quill', 'ssh_url_to_repo': 'git@gitlab.com:shaharia/quill.git', 'star_count': 0, '_id': ObjectId('5bc4f182856cc608756724b4'), 'name_with_namespace': 'Shaharia Azam / quill', 'web_url': 'https://gitlab.com/shaharia/quill', 'avatar_url': None, 'path_with_namespace': 'shaharia/quill', 'id': 8694176, 'forks_count': 0, 'description': 'Quill is a modern WYSIWYG editor built for compatibility and extensibility.', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'AugustoF.Tavares', 'id': 3737895, 'full_path': 'AugustoF.Tavares', 'path': 'AugustoF.Tavares', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T02:21:20.165Z', 'name': 'Quiz', 'http_url_to_repo': 'https://gitlab.com/AugustoF.Tavares/quiz.git', 'readme_url': 'https://gitlab.com/AugustoF.Tavares/quiz/blob/master/README.md', 'last_activity_at': '2018-10-09T17:00:13.970Z', 'path': 'quiz', 'ssh_url_to_repo': 'git@gitlab.com:AugustoF.Tavares/quiz.git', 'star_count': 0, '_id': ObjectId('5bc4f190856cc608756724b5'), 'name_with_namespace': 'ANTONIO AUGUSTO FARIAS TAVARES / Quiz', 'web_url': 'https://gitlab.com/AugustoF.Tavares/quiz', 'avatar_url': None, 'path_with_namespace': 'AugustoF.Tavares/quiz', 'id': 8690991, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'ih8sum3r', 'id': 93364, 'full_path': 'ih8sum3r', 'path': 'ih8sum3r', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-04T01:30:41.494Z', 'name': 'qa-rails-app', 'http_url_to_repo': 'https://gitlab.com/ih8sum3r/qa-rails-app.git', 'readme_url': 'https://gitlab.com/ih8sum3r/qa-rails-app/blob/master/README.md', 'last_activity_at': '2018-10-09T23:49:23.513Z', 'path': 'qa-rails-app', 'ssh_url_to_repo': 'git@gitlab.com:ih8sum3r/qa-rails-app.git', 'star_count': 0, '_id': ObjectId('5bc4f196856cc608756724b6'), 'name_with_namespace': 'ih8sum3r / qa-rails-app', 'web_url': 'https://gitlab.com/ih8sum3r/qa-rails-app', 'avatar_url': None, 'path_with_namespace': 'ih8sum3r/qa-rails-app', 'id': 8690570, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'candres0819', 'id': 2173542, 'full_path': 'candres0819', 'path': 'candres0819', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-03T23:55:31.211Z', 'name': 'quemaravilla', 'http_url_to_repo': 'https://gitlab.com/candres0819/quemaravilla.git', 'readme_url': 'https://gitlab.com/candres0819/quemaravilla/blob/master/README.md', 'last_activity_at': '2018-10-03T23:55:31.211Z', 'path': 'quemaravilla', 'ssh_url_to_repo': 'git@gitlab.com:candres0819/quemaravilla.git', 'star_count': 0, '_id': ObjectId('5bc4f19b856cc608756724b7'), 'name_with_namespace': 'Carlos Andrés Cardona M / quemaravilla', 'web_url': 'https://gitlab.com/candres0819/quemaravilla', 'avatar_url': None, 'path_with_namespace': 'candres0819/quemaravilla', 'id': 8689995, 'forks_count': 0, 'description': 'Rubelio - El maravilloso guia turistico de Medellín! Ganador del Hackaton Cognitivo', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'dbank888', 'id': 3736703, 'full_path': 'dbank888', 'path': 'dbank888', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-03T20:27:43.661Z', 'name': 'qqzeng-ip', 'http_url_to_repo': 'https://gitlab.com/dbank888/qqzeng-ip.git', 'readme_url': 'https://gitlab.com/dbank888/qqzeng-ip/blob/master/README.md', 'last_activity_at': '2018-10-03T20:27:43.661Z', 'path': 'qqzeng-ip', 'ssh_url_to_repo': 'git@gitlab.com:dbank888/qqzeng-ip.git', 'star_count': 0, '_id': ObjectId('5bc4f1a4856cc608756724b8'), 'name_with_namespace': 'oio / qqzeng-ip', 'web_url': 'https://gitlab.com/dbank888/qqzeng-ip', 'avatar_url': None, 'path_with_namespace': 'dbank888/qqzeng-ip', 'id': 8688261, 'forks_count': 0, 'description': 'ć\x9c\x80ć\x96°IPĺ\x9c°ĺ\x9d\x80ć\x95°ć\x8dŽĺş\x93-ĺ¤\x9ačŻ\xadč¨\x80č§Łć\x9e\x90äťĽĺ\x8f\x8aĺŻźĺ\x85Ľć\x95°ć\x8dŽĺş\x93č\x84\x9ać\x9cŹ', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'ajesse11x', 'id': 3714404, 'full_path': 'ajesse11x', 'path': 'ajesse11x', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-03T20:13:01.234Z', 'name': 'QuantumKatas', 'http_url_to_repo': 'https://gitlab.com/ajesse11x/QuantumKatas.git', 'readme_url': 'https://gitlab.com/ajesse11x/QuantumKatas/blob/master/README.md', 'last_activity_at': '2018-10-03T20:13:01.234Z', 'path': 'QuantumKatas', 'ssh_url_to_repo': 'git@gitlab.com:ajesse11x/QuantumKatas.git', 'star_count': 0, '_id': ObjectId('5bc4f1af856cc608756724b9'), 'name_with_namespace': 'ajesse11x / QuantumKatas', 'web_url': 'https://gitlab.com/ajesse11x/QuantumKatas', 'avatar_url': None, 'path_with_namespace': 'ajesse11x/QuantumKatas', 'id': 8688022, 'forks_count': 0, 'description': 'Programming exercises for learning Q# and quantum computing', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'BluestNight', 'id': 1956385, 'full_path': 'BluestNight', 'path': 'BluestNight', 'kind': 'group'}, 'tag_list': [], 'created_at': '2018-10-03T16:52:55.197Z', 'name': 'Quasar', 'http_url_to_repo': 'https://gitlab.com/BluestNight/quasar.git', 'readme_url': 'https://gitlab.com/BluestNight/quasar/blob/master/README.md', 'last_activity_at': '2018-10-11T17:16:34.871Z', 'path': 'quasar', 'ssh_url_to_repo': 'git@gitlab.com:BluestNight/quasar.git', 'star_count': 0, '_id': ObjectId('5bc4f1bc856cc608756724ba'), 'name_with_namespace': 'BluestNight / Quasar', 'web_url': 'https://gitlab.com/BluestNight/quasar', 'avatar_url': None, 'path_with_namespace': 'BluestNight/quasar', 'id': 8685466, 'forks_count': 0, 'description': 'Login provider and library', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'sbf-binnen', 'id': 3735701, 'full_path': 'sbf-binnen', 'path': 'sbf-binnen', 'kind': 'group'}, 'tag_list': ['parser', 'python', 'sbf'], 'created_at': '2018-10-03T16:03:05.584Z', 'name': 'questions-parser', 'http_url_to_repo': 'https://gitlab.com/sbf-binnen/questions-parser.git', 'readme_url': 'https://gitlab.com/sbf-binnen/questions-parser/blob/master/README.md', 'last_activity_at': '2018-10-05T07:35:18.391Z', 'path': 'questions-parser', 'ssh_url_to_repo': 'git@gitlab.com:sbf-binnen/questions-parser.git', 'star_count': 0, '_id': ObjectId('5bc4f1c1856cc608756724bb'), 'name_with_namespace': 'sbf-binnen / questions-parser', 'web_url': 'https://gitlab.com/sbf-binnen/questions-parser', 'avatar_url': None, 'path_with_namespace': 'sbf-binnen/questions-parser', 'id': 8684749, 'forks_count': 0, 'description': 'Parser to convert HTML Questions and Answers into JSON Format, from www.elwis.de', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'saint_shark', 'id': 3731575, 'full_path': 'saint_shark', 'path': 'saint_shark', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-03T12:47:29.100Z', 'name': 'QEMU-scripts', 'http_url_to_repo': 'https://gitlab.com/saint_shark/QEMU-scripts.git', 'readme_url': 'https://gitlab.com/saint_shark/QEMU-scripts/blob/master/README.md', 'last_activity_at': '2018-10-03T12:47:29.100Z', 'path': 'QEMU-scripts', 'ssh_url_to_repo': 'git@gitlab.com:saint_shark/QEMU-scripts.git', 'star_count': 0, '_id': ObjectId('5bc4f1d5856cc608756724bc'), 'name_with_namespace': 'Aaditya Chaudhary / QEMU-scripts', 'web_url': 'https://gitlab.com/saint_shark/QEMU-scripts', 'avatar_url': None, 'path_with_namespace': 'saint_shark/QEMU-scripts', 'id': 8681269, 'forks_count': 0, 'description': 'Python scripts for managing multiple VMs  ', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'crep4ever', 'id': 3733190, 'full_path': 'crep4ever', 'path': 'crep4ever', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-03T10:10:53.600Z', 'name': 'QCustomPlot', 'http_url_to_repo': 'https://gitlab.com/crep4ever/QCustomPlot.git', 'readme_url': None, 'last_activity_at': '2018-10-03T12:17:00.813Z', 'path': 'QCustomPlot', 'ssh_url_to_repo': 'git@gitlab.com:crep4ever/QCustomPlot.git', 'star_count': 0, '_id': ObjectId('5bc4f1e7856cc608756724bd'), 'name_with_namespace': 'Romain Goffe / QCustomPlot', 'web_url': 'https://gitlab.com/crep4ever/QCustomPlot', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8678829/qcp-git-avatar.png', 'path_with_namespace': 'crep4ever/QCustomPlot', 'id': 8678829, 'forks_count': 0, 'description': 'QCustomPlot is an easy to use plotting widget for Qt.\r\n\r\n\r\nVisit — www.qcustomplot.com — to get the current release.', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'andersenq', 'id': 540190, 'full_path': 'andersenq', 'path': 'andersenq', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-03T08:10:08.675Z', 'name': 'QDK', 'http_url_to_repo': 'https://gitlab.com/andersenq/QDK.git', 'readme_url': 'https://gitlab.com/andersenq/QDK/blob/master/README.md', 'last_activity_at': '2018-10-03T08:10:08.675Z', 'path': 'QDK', 'ssh_url_to_repo': 'git@gitlab.com:andersenq/QDK.git', 'star_count': 0, '_id': ObjectId('5bc4f1f0856cc608756724be'), 'name_with_namespace': 'Andersen Huang / QDK', 'web_url': 'https://gitlab.com/andersenq/QDK', 'avatar_url': None, 'path_with_namespace': 'andersenq/QDK', 'id': 8676929, 'forks_count': 0, 'description': 'QNAP Development Kit for APIM', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'thiagomg', 'id': 471471, 'full_path': 'thiagomg', 'path': 'thiagomg', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-03T06:52:51.680Z', 'name': 'quickfix-cpp17', 'http_url_to_repo': 'https://gitlab.com/thiagomg/quickfix-cpp17.git', 'readme_url': 'https://gitlab.com/thiagomg/quickfix-cpp17/blob/master/README.md', 'last_activity_at': '2018-10-03T06:52:51.680Z', 'path': 'quickfix-cpp17', 'ssh_url_to_repo': 'git@gitlab.com:thiagomg/quickfix-cpp17.git', 'star_count': 0, '_id': ObjectId('5bc4f1fb856cc608756724bf'), 'name_with_namespace': 'Thiago Massari Guedes / quickfix-cpp17', 'web_url': 'https://gitlab.com/thiagomg/quickfix-cpp17', 'avatar_url': None, 'path_with_namespace': 'thiagomg/quickfix-cpp17', 'id': 8675403, 'forks_count': 0, 'description': 'quickfix library fork, compatible with c++17', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'toniVarga', 'id': 1300040, 'full_path': 'toniVarga', 'path': 'toniVarga', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-02T23:21:57.546Z', 'name': 'qapass_lcd', 'http_url_to_repo': 'https://gitlab.com/toniVarga/qapass_lcd.git', 'readme_url': 'https://gitlab.com/toniVarga/qapass_lcd/blob/master/README.md', 'last_activity_at': '2018-10-09T17:50:31.708Z', 'path': 'qapass_lcd', 'ssh_url_to_repo': 'git@gitlab.com:toniVarga/qapass_lcd.git', 'star_count': 0, '_id': ObjectId('5bc4f20a856cc608756724c0'), 'name_with_namespace': 'Toni Varga / qapass_lcd', 'web_url': 'https://gitlab.com/toniVarga/qapass_lcd', 'avatar_url': None, 'path_with_namespace': 'toniVarga/qapass_lcd', 'id': 8671877, 'forks_count': 0, 'description': 'Library for 2x16 LCD Dysplay', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'ankur.singh4012', 'id': 525920, 'full_path': 'ankur.singh4012', 'path': 'ankur.singh4012', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-02T22:24:33.361Z', 'name': 'qa-test-hf', 'http_url_to_repo': 'https://gitlab.com/ankur.singh4012/qa-test-hf.git', 'readme_url': 'https://gitlab.com/ankur.singh4012/qa-test-hf/blob/master/readme.md', 'last_activity_at': '2018-10-07T12:05:54.775Z', 'path': 'qa-test-hf', 'ssh_url_to_repo': 'git@gitlab.com:ankur.singh4012/qa-test-hf.git', 'star_count': 0, '_id': ObjectId('5bc4f20f856cc608756724c1'), 'name_with_namespace': 'Ankur Singh / qa-test-hf', 'web_url': 'https://gitlab.com/ankur.singh4012/qa-test-hf', 'avatar_url': None, 'path_with_namespace': 'ankur.singh4012/qa-test-hf', 'id': 8671519, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'vovannov', 'id': 3063066, 'full_path': 'vovannov', 'path': 'vovannov', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-02T18:43:46.175Z', 'name': 'quicknotes', 'http_url_to_repo': 'https://gitlab.com/vovannov/quicknotes.git', 'readme_url': 'https://gitlab.com/vovannov/quicknotes/blob/master/README.md', 'last_activity_at': '2018-10-02T18:43:46.175Z', 'path': 'quicknotes', 'ssh_url_to_repo': 'git@gitlab.com:vovannov/quicknotes.git', 'star_count': 0, '_id': ObjectId('5bc4f21e856cc608756724c2'), 'name_with_namespace': 'Vladimir Pastukhov / quicknotes', 'web_url': 'https://gitlab.com/vovannov/quicknotes', 'avatar_url': None, 'path_with_namespace': 'vovannov/quicknotes', 'id': 8668745, 'forks_count': 0, 'description': 'A simple qicknotes widget written in Python 3', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'luchk', 'id': 3020264, 'full_path': 'luchk', 'path': 'luchk', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-02T18:27:47.326Z', 'name': 'quadratic equation Haskell', 'http_url_to_repo': 'https://gitlab.com/luchk/quadratic-equation-haskell.git', 'readme_url': 'https://gitlab.com/luchk/quadratic-equation-haskell/blob/master/README.md', 'last_activity_at': '2018-10-02T18:27:47.326Z', 'path': 'quadratic-equation-haskell', 'ssh_url_to_repo': 'git@gitlab.com:luchk/quadratic-equation-haskell.git', 'star_count': 0, '_id': ObjectId('5bc4f21f856cc608756724c3'), 'name_with_namespace': 'luchk / quadratic equation Haskell', 'web_url': 'https://gitlab.com/luchk/quadratic-equation-haskell', 'avatar_url': None, 'path_with_namespace': 'luchk/quadratic-equation-haskell', 'id': 8668539, 'forks_count': 0, 'description': '', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'kaili', 'id': 1626630, 'full_path': 'kaili', 'path': 'kaili', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-02T17:32:02.629Z', 'name': 'qwebsite', 'http_url_to_repo': 'https://gitlab.com/kaili/qwebsite.git', 'readme_url': 'https://gitlab.com/kaili/qwebsite/blob/master/README', 'last_activity_at': '2018-10-12T07:34:59.082Z', 'path': 'qwebsite', 'ssh_url_to_repo': 'git@gitlab.com:kaili/qwebsite.git', 'star_count': 0, '_id': ObjectId('5bc4f224856cc608756724c4'), 'name_with_namespace': 'Kai Peter / qwebsite', 'web_url': 'https://gitlab.com/kaili/qwebsite', 'avatar_url': None, 'path_with_namespace': 'kaili/qwebsite', 'id': 8667775, 'forks_count': 0, 'description': None, 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'saimunhossain', 'id': 1056388, 'full_path': 'saimunhossain', 'path': 'saimunhossain', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-02T16:33:44.032Z', 'name': 'QuestionNAnswerApp', 'http_url_to_repo': 'https://gitlab.com/saimunhossain/questionnanswerapp.git', 'readme_url': 'https://gitlab.com/saimunhossain/questionnanswerapp/blob/master/readme.md', 'last_activity_at': '2018-10-14T19:42:09.568Z', 'path': 'questionnanswerapp', 'ssh_url_to_repo': 'git@gitlab.com:saimunhossain/questionnanswerapp.git', 'star_count': 0, '_id': ObjectId('5bc4f228856cc608756724c5'), 'name_with_namespace': 'Md Saimun Hossain / QuestionNAnswerApp', 'web_url': 'https://gitlab.com/saimunhossain/questionnanswerapp', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8667050/q.jpg', 'path_with_namespace': 'saimunhossain/questionnanswerapp', 'id': 8667050, 'forks_count': 0, 'description': 'A simple question and answer application using laravel', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'ashishpatel0720', 'id': 1730371, 'full_path': 'ashishpatel0720', 'path': 'ashishpatel0720', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-02T15:17:01.465Z', 'name': 'qtube', 'http_url_to_repo': 'https://gitlab.com/ashishpatel0720/qtube.git', 'readme_url': 'https://gitlab.com/ashishpatel0720/qtube/blob/master/readme.md', 'last_activity_at': '2018-10-02T15:17:01.465Z', 'path': 'qtube', 'ssh_url_to_repo': 'git@gitlab.com:ashishpatel0720/qtube.git', 'star_count': 0, '_id': ObjectId('5bc4f22e856cc608756724c6'), 'name_with_namespace': 'Ashish Patel / qtube', 'web_url': 'https://gitlab.com/ashishpatel0720/qtube', 'avatar_url': None, 'path_with_namespace': 'ashishpatel0720/qtube', 'id': 8665909, 'forks_count': 0, 'description': 'Create REST API with authentication using Laravel Passport  http://www.qcode.in/create-rest-api-authentication-using-laravel-passport/', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'ashishpatel0720', 'id': 1730371, 'full_path': 'ashishpatel0720', 'path': 'ashishpatel0720', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-02T15:17:00.647Z', 'name': 'qTwitter', 'http_url_to_repo': 'https://gitlab.com/ashishpatel0720/qTwitter.git', 'readme_url': 'https://gitlab.com/ashishpatel0720/qTwitter/blob/master/README.md', 'last_activity_at': '2018-10-02T15:17:00.647Z', 'path': 'qTwitter', 'ssh_url_to_repo': 'git@gitlab.com:ashishpatel0720/qTwitter.git', 'star_count': 0, '_id': ObjectId('5bc4f22e856cc608756724c7'), 'name_with_namespace': 'Ashish Patel / qTwitter', 'web_url': 'https://gitlab.com/ashishpatel0720/qTwitter', 'avatar_url': None, 'path_with_namespace': 'ashishpatel0720/qTwitter', 'id': 8665907, 'forks_count': 0, 'description': 'A Twitter like app build using Laravel Vue.js and GraphQL by http://www.qcode.in', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'jack_poulson', 'id': 3589093, 'full_path': 'jack_poulson', 'path': 'jack_poulson', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-02T14:18:41.154Z', 'name': 'quotient', 'http_url_to_repo': 'https://gitlab.com/jack_poulson/quotient.git', 'readme_url': 'https://gitlab.com/jack_poulson/quotient/blob/master/README.md', 'last_activity_at': '2018-10-15T18:02:05.315Z', 'path': 'quotient', 'ssh_url_to_repo': 'git@gitlab.com:jack_poulson/quotient.git', 'star_count': 2, '_id': ObjectId('5bc4f233856cc608756724c8'), 'name_with_namespace': 'Jack Poulson / quotient', 'web_url': 'https://gitlab.com/jack_poulson/quotient', 'avatar_url': None, 'path_with_namespace': 'jack_poulson/quotient', 'id': 8664845, 'forks_count': 1, 'description': 'A C++14 implementation of the (Approximate) Minimum Degree reordering algorithm for sparse Symmetric Quasi-SemiDefinite (SQSD) Cholesky factorization.', 'forge': 'gitlab', 'default_branch': 'master'}
# {'namespace': {'parent_id': None, 'name': 'vincentcox', 'id': 199216, 'full_path': 'vincentcox', 'path': 'vincentcox', 'kind': 'user'}, 'tag_list': [], 'created_at': '2018-10-02T13:58:35.144Z', 'name': 'QNAP-pushover', 'http_url_to_repo': 'https://gitlab.com/vincentcox/QNAP-pushover.git', 'readme_url': 'https://gitlab.com/vincentcox/QNAP-pushover/blob/master/README.md', 'last_activity_at': '2018-10-02T13:58:35.144Z', 'path': 'QNAP-pushover', 'ssh_url_to_repo': 'git@gitlab.com:vincentcox/QNAP-pushover.git', 'star_count': 0, '_id': ObjectId('5bc4f239856cc608756724c9'), 'name_with_namespace': 'Vincent / QNAP-pushover', 'web_url': 'https://gitlab.com/vincentcox/QNAP-pushover', 'avatar_url': None, 'path_with_namespace': 'vincentcox/QNAP-pushover', 'id': 8664503, 'forks_count': 0, 'description': 'Pushover notification for QNAP NAS system events', 'forge': 'gitlab', 'default_branch': 'master'}
# {'video_url': '', 'moved_to_url': '', 'status': 'active', 'socialnetworks': [], '_id': '4f63576c0594ca14b200097f', 'summary': 'DEXONE', 'categories': {'translation': [], 'environment': [], 'os': [], 'developmentstatus': [], 'database': [], 'audience': [], 'language': [], 'license': [], 'topic': []}, 'labels': [], 'screenshots': [], 'creation_date': '2012-03-16', 'shortname': 'qrgarjmn', 'forge': 'sourceforge', 'preferred_support_url': '', 'name': 'BUY ONLINE GENERIC DEXONE', 'url': 'https://sourceforge.net/p/qrgarjmn/', 'external_homepage': '', 'icon_url': None, 'developers': [{'url': 'https://sourceforge.net/u/dcwilliamsa/', 'name': 'Roxana Manes', 'username': 'dcwilliamsa'}], 'tools': [{'installable': False, 'url': '/p/qrgarjmn/files/', 'name': 'files', 'mount_point': 'files', 'mount_label': 'Files', 'icons': {'24': 'images/downloads_24.png', '48': 'images/downloads_48.png', '32': 'images/downloads_32.png'}, 'tool_label': 'Files'}, {'installable': True, 'url': '/p/qrgarjmn/tickets/', 'name': 'tickets', 'mount_point': 'tickets', 'mount_label': 'Tickets', 'icons': {'24': 'images/tickets_24.png', '48': 'images/tickets_48.png', '32': 'images/tickets_32.png'}, 'tool_label': 'Tickets'}, {'installable': True, 'url': '/p/qrgarjmn/code/', 'name': 'git', 'mount_point': 'code', 'mount_label': 'Code', 'icons': {'24': 'images/code_24.png', '48': 'images/code_48.png', '32': 'images/code_32.png'}, 'tool_label': 'Git'}, {'installable': True, 'url': '/p/qrgarjmn/wiki/', 'name': 'wiki', 'mount_point': 'wiki', 'mount_label': 'Wiki', 'icons': {'24': 'images/wiki_24.png', '48': 'images/wiki_48.png', '32': 'images/wiki_32.png'}, 'tool_label': 'Wiki'}, {'installable': True, 'url': '/p/qrgarjmn/discussion/', 'name': 'discussion', 'mount_point': 'discussion', 'mount_label': 'Discussion', 'icons': {'24': 'images/forums_24.png', '48': 'images/forums_48.png', '32': 'images/forums_32.png'}, 'tool_label': 'Discussion'}, {'installable': False, 'url': '/p/qrgarjmn/support/', 'name': 'support', 'mount_point': 'support', 'mount_label': 'Support', 'icons': {'24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'tool_label': 'Support'}, {'installable': False, 'url': '/p/qrgarjmn/reviews/', 'name': 'reviews', 'mount_point': 'reviews', 'mount_label': 'Reviews', 'icons': {'24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'tool_label': 'Reviews'}, {'installable': False, 'url': '/p/qrgarjmn/summary/', 'name': 'summary', 'mount_point': 'summary', 'sourceforge_group_id': 724477, 'mount_label': 'Summary', 'icons': {'24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'tool_label': 'Summary'}, {'installable': False, 'url': '/p/qrgarjmn/activity/', 'name': 'activity', 'mount_point': 'activity', 'mount_label': 'Activity', 'icons': {'24': 'images/admin_24.png', '48': 'images/admin_48.png', '32': 'images/admin_32.png'}, 'tool_label': 'Tool'}], 'short_description': '\r\nPURCHASE CHEAP ONLINE DEXONE IN INTERNET FREE SHIPPING\r\n.\r\n.\r\n<b>CLICK BELOW ON THE LINK</b>\r\n.\r\n>>>>> http://totalworldstore.com/shop/go.php?sid=5&search=DEXONE <<<<<\r\n.\r\n.\r\n.\r\nRELATED LINKS\r\nhttp://www.projectsavage.com/?q=content/online-cheap-pharmacy-metoclopramide-internet-no-doctors;\r\nhttp://dcwilliam.posterous.com/;\r\nhttp://www.projectsavage.com/?q=content/buy-online-canada-prednisone-overnight-delivery;\r\nhttp://www.projectsavage.com/?q=content/low-price-rhinocort-discount-pharmacy-online;\r\nhttp://www.projectsavage.com/?q=content/discount-zyprexa-free-prescription-drug;\r\nhttp://www.projectsavage.com/?q=content/best-prices-omnicef-overnight-delivery;\r\nhttp://www.projectsavage.com/?q=content/purchase-cheap-online-entocort-non-prescription;\r\nhttp://buyprilosecinusa.webs.com/', 'preferred_support_tool': '', 'private': False}
# ...
# {'video_url': '', 'moved_to_url': '', 'status': 'active', 'socialnetworks': [], '_id': '5148ad98e88f3d5571aa37c1', 'summary': '', 'categories': {'translation': [{'id': 275, 'fullpath': 'Translations :: English', 'fullname': 'English', 'shortname': 'english'}], 'environment': [{'id': 230, 'fullpath': 'User Interface :: Graphical :: Win32 (MS Windows)', 'fullname': 'Win32 (MS Windows)', 'shortname': 'win32'}, {'id': 314, 'fullpath': 'User Interface :: Graphical :: Handheld/Mobile/PDA', 'fullname': 'Handheld/Mobile/PDA', 'shortname': 'handhelds'}], 'os': [{'id': 218, 'fullpath': 'Operating System :: Grouping and Descriptive Categories :: 32-bit MS Windows (95/98)', 'fullname': '32-bit MS Windows (95/98)', 'shortname': 'win95'}, {'id': 435, 'fullpath': 'Operating System :: Grouping and Descriptive Categories :: All 32-bit MS Windows (95/98/NT/2000/XP)', 'fullname': 'All 32-bit MS Windows (95/98/NT/2000/XP)', 'shortname': 'mswin_all32bit'}], 'developmentstatus': [{'id': 7, 'fullpath': 'Development Status :: 1 - Planning', 'fullname': '1 - Planning', 'shortname': 'planning'}], 'database': [], 'audience': [{'id': 359, 'fullpath': 'Intended Audience :: by Industry or Sector :: Customer Service', 'fullname': 'Customer Service', 'shortname': 'customerservice'}, {'id': 3, 'fullpath': 'Intended Audience :: by End-User Class :: Developers', 'fullname': 'Developers', 'shortname': 'developers'}, {'id': 2, 'fullpath': 'Intended Audience :: by End-User Class :: End Users/Desktop', 'fullname': 'End Users/Desktop', 'shortname': 'endusers'}, {'id': 5, 'fullpath': 'Intended Audience :: Other Audience', 'fullname': 'Other Audience', 'shortname': 'other'}], 'language': [{'id': 271, 'fullpath': 'Programming Language :: C#', 'fullname': 'C#', 'shortname': 'csharp'}], 'license': [{'id': 187, 'fullpath': 'License :: OSI-Approved Open Source :: BSD License', 'fullname': 'BSD License', 'shortname': 'bsd'}], 'topic': [{'id': 130, 'fullpath': 'Topic :: Office/Business :: Scheduling', 'fullname': 'Scheduling', 'shortname': 'scheduling'}]}, 'labels': [], 'screenshots': [], 'creation_date': '2004-06-12', 'shortname': 'qcustomer', 'forge': 'sourceforge', 'preferred_support_url': 'http://sourceforge.net/forum/forum.php?forum_id=382984', 'name': 'Q-Customer', 'url': 'https://sourceforge.net/p/qcustomer/', 'external_homepage': 'https://qcustomer.sourceforge.io', 'icon_url': None, 'developers': [{'url': 'https://sourceforge.net/u/ghzdesigns/', 'name': 'GhzDesigns', 'username': 'ghzdesigns'}, {'url': 'https://sourceforge.net/u/talevil/', 'name': 'tamir', 'username': 'talevil'}, {'url': 'https://sourceforge.net/u/ejcroyle/', 'name': 'Eric J. Croyle', 'username': 'ejcroyle'}, {'url': 'https://sourceforge.net/u/pushpalathac/', 'name': 'Pushpa', 'username': 'pushpalathac'}, {'url': 'https://sourceforge.net/u/privatevoid/', 'name': 'PrivateVoid', 'username': 'privatevoid'}], 'tools': [{'installable': False, 'url': '/p/qcustomer/reviews/', 'name': 'reviews', 'mount_point': 'reviews', 'mount_label': 'Reviews', 'icons': {'24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'tool_label': 'Reviews'}, {'installable': True, 'url': '/p/qcustomer/discussion/', 'name': 'discussion', 'mount_point': 'discussion', 'mount_label': 'Discussion', 'icons': {'24': 'images/forums_24.png', '48': 'images/forums_48.png', '32': 'images/forums_32.png'}, 'tool_label': 'Discussion'}, {'installable': True, 'url': '/p/qcustomer/wiki/', 'name': 'wiki', 'mount_point': 'wiki', 'mount_label': 'Wiki', 'icons': {'24': 'images/wiki_24.png', '48': 'images/wiki_48.png', '32': 'images/wiki_32.png'}, 'tool_label': 'Wiki'}, {'installable': True, 'url': '/p/qcustomer/news/', 'name': 'blog', 'mount_point': 'news', 'mount_label': 'News', 'icons': {'24': 'images/blog_24.png', '48': 'images/blog_48.png', '32': 'images/blog_32.png'}, 'tool_label': 'Blog'}, {'installable': False, 'url': '/p/qcustomer/support/', 'name': 'support', 'mount_point':  ...
# {'video_url': '', 'moved_to_url': '', 'status': 'active', 'socialnetworks': [], '_id': '5176b7ad2718467af2db42ff', 'summary': '', 'categories': {'translation': [], 'environment': [{'id': 237, 'fullpath': 'User Interface :: Web-based', 'fullname': 'Web-based', 'shortname': 'web'}], 'os': [{'id': 436, 'fullpath': 'Operating System :: Grouping and Descriptive Categories :: OS Portable (Source code to work with many OS platforms)', 'fullname': 'OS Portable (Source code to work with many OS platforms)', 'shortname': 'os_portable'}], 'developmentstatus': [{'id': 8, 'fullpath': 'Development Status :: 2 - Pre-Alpha', 'fullname': '2 - Pre-Alpha', 'shortname': 'prealpha'}], 'database': [{'id': 524, 'fullpath': 'Database Environment :: Network-based DBMS :: MySQL', 'fullname': 'MySQL', 'shortname': 'db_net_mysql'}], 'audience': [{'id': 365, 'fullpath': 'Intended Audience :: by Industry or Sector :: Manufacturing', 'fullname': 'Manufacturing', 'shortname': 'manufacturing'}, {'id': 2, 'fullpath': 'Intended Audience :: by End-User Class :: End Users/Desktop', 'fullname': 'End Users/Desktop', 'shortname': 'endusers'}], 'language': [{'id': 280, 'fullpath': 'Programming Language :: JavaScript', 'fullname': 'JavaScript', 'shortname': 'JavaScript'}, {'id': 198, 'fullpath': 'Programming Language :: Java', 'fullname': 'Java', 'shortname': 'java'}], 'license': [{'id': 187, 'fullpath': 'License :: OSI-Approved Open Source :: BSD License', 'fullname': 'BSD License', 'shortname': 'bsd'}], 'topic': [{'id': 577, 'fullpath': 'Topic :: Office/Business :: Enterprise :: ERP', 'fullname': 'ERP', 'shortname': 'erp'}]}, 'labels': [], 'screenshots': [], 'creation_date': '2008-05-25', 'shortname': 'qerp', 'forge': 'sourceforge', 'preferred_support_url': '', 'name': 'Q-ERP', 'url': 'https://sourceforge.net/p/qerp/', 'external_homepage': 'https://qerp.sourceforge.io', 'icon_url': None, 'developers': [{'url': 'https://sourceforge.net/u/cybertan/', 'name': 'cybertan', 'username': 'cybertan'}, {'url': 'https://sourceforge.net/u/cyberkoa/', 'name': 'Koa CG', 'username': 'cyberkoa'}, {'url': 'https://sourceforge.net/u/kylelimws/', 'name': 'Kyle Lim', 'username': 'kylelimws'}], 'tools': [{'installable': False, 'url': '/p/qerp/support/', 'name': 'support', 'mount_point': 'support', 'mount_label': 'Support', 'icons': {'24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'tool_label': 'Support'}, {'installable': False, 'url': '/p/qerp/reviews/', 'name': 'reviews', 'mount_point': 'reviews', 'mount_label': 'Reviews', 'icons': {'24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'tool_label': 'Reviews'}, {'installable': True, 'url': '/p/qerp/code/', 'name': 'svn', 'mount_point': 'code', 'mount_label': 'Code', 'icons': {'24': 'images/code_24.png', '48': 'images/code_48.png', '32': 'images/code_32.png'}, 'tool_label': 'SVN'}, {'installable': True, 'url': '/p/qerp/wiki/', 'name': 'wiki', 'mount_point': 'wiki', 'mount_label': 'Wiki', 'icons': {'24': 'images/wiki_24.png', '48': 'images/wiki_48.png', '32': 'images/wiki_32.png'}, 'tool_label': 'Wiki'}, {'installable': False, 'url': '/p/qerp/files/', 'name': 'files', 'mount_point': 'files', 'mount_label': 'Files', 'icons': {'24': 'images/downloads_24.png', '48': 'images/downloads_48.png', '32': 'images/downloads_32.png'}, 'tool_label': 'Files'}, {'installable': False, 'url': '/p/qerp/summary/', 'name': 'summary', 'mount_point': 'summary', 'sourceforge_group_id': 229161, 'mount_label': 'Summary', 'icons': {'24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'tool_label': 'Summary'}, {'installable': True, 'url': '/p/qerp/bugs/', 'name': 'tickets', 'mount_point': 'bugs', 'mount_label': 'Bugs', 'icons': {'24': 'images/tickets_24.png', '48': 'images/tickets_48.png', '32': 'images/tickets_32.png'}, 'tool_label': 'Ticket ...
# {'video_url': '', 'moved_to_url': '', 'status': 'active', 'socialnetworks': [], '_id': '516eef5b34309d5ba8e7ed78', 'summary': '', 'categories': {'translation': [], 'environment': [], 'os': [], 'developmentstatus': [{'id': 8, 'fullpath': 'Development Status :: 2 - Pre-Alpha', 'fullname': '2 - Pre-Alpha', 'shortname': 'prealpha'}], 'database': [], 'audience': [{'id': 360, 'fullpath': 'Intended Audience :: by Industry or Sector :: Education', 'fullname': 'Education', 'shortname': 'education'}], 'language': [{'id': 198, 'fullpath': 'Programming Language :: Java', 'fullname': 'Java', 'shortname': 'java'}], 'license': [{'id': 16, 'fullpath': 'License :: OSI-Approved Open Source :: GNU Library or Lesser General Public License version 2.0 (LGPLv2)', 'fullname': 'GNU Library or Lesser General Public License version 2.0 (LGPLv2)', 'shortname': 'lgpl'}], 'topic': [{'id': 73, 'fullpath': 'Topic :: Education :: Testing', 'fullname': 'Testing', 'shortname': 'testing'}]}, 'labels': [], 'screenshots': [], 'creation_date': '2007-01-26', 'shortname': 'quiz-engine', 'forge': 'sourceforge', 'preferred_support_url': '', 'name': 'Q-Engine', 'url': 'https://sourceforge.net/p/quiz-engine/', 'external_homepage': 'https://quiz-engine.sourceforge.io', 'icon_url': None, 'developers': [{'url': 'https://sourceforge.net/u/userid-1253837/', 'name': 'Nitin', 'username': 'k_nitin_r'}], 'tools': [{'installable': False, 'url': '/p/quiz-engine/reviews/', 'name': 'reviews', 'mount_point': 'reviews', 'mount_label': 'Reviews', 'icons': {'24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'tool_label': 'Reviews'}, {'installable': False, 'url': '/p/quiz-engine/summary/', 'name': 'summary', 'mount_point': 'summary', 'sourceforge_group_id': 187940, 'mount_label': 'Summary', 'icons': {'24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'tool_label': 'Summary'}, {'installable': False, 'url': '/p/quiz-engine/files/', 'name': 'files', 'mount_point': 'files', 'mount_label': 'Files', 'icons': {'24': 'images/downloads_24.png', '48': 'images/downloads_48.png', '32': 'images/downloads_32.png'}, 'tool_label': 'Files'}, {'installable': True, 'url': '/p/quiz-engine/wiki/', 'name': 'wiki', 'mount_point': 'wiki', 'mount_label': 'Wiki', 'icons': {'24': 'images/wiki_24.png', '48': 'images/wiki_48.png', '32': 'images/wiki_32.png'}, 'tool_label': 'Wiki'}, {'installable': True, 'url': '/p/quiz-engine/code/', 'name': 'svn', 'mount_point': 'code', 'mount_label': 'Code', 'icons': {'24': 'images/code_24.png', '48': 'images/code_48.png', '32': 'images/code_32.png'}, 'tool_label': 'SVN'}, {'installable': False, 'url': '/p/quiz-engine/cvs/', 'name': 'cvs', 'mount_point': 'cvs', 'mount_label': 'Cvs', 'icons': {'24': 'images/code_24.png', '48': 'images/code_48.png', '32': 'images/code_32.png'}, 'tool_label': 'CVS'}, {'installable': False, 'url': '/p/quiz-engine/support/', 'name': 'support', 'mount_point': 'support', 'mount_label': 'Support', 'icons': {'24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'tool_label': 'Support'}, {'installable': False, 'url': '/p/quiz-engine/activity/', 'name': 'activity', 'mount_point': 'activity', 'mount_label': 'Activity', 'icons': {'24': 'images/admin_24.png', '48': 'images/admin_48.png', '32': 'images/admin_32.png'}, 'tool_label': 'Tool'}], 'short_description': 'An interactive learning, testing and evaluation system', 'preferred_support_tool': '', 'private': False}
# {'video_url': '', 'moved_to_url': '', 'status': 'active', 'socialnetworks': [], '_id': '517822d1e88f3d77decae3dd', 'summary': '', 'categories': {'translation': [], 'environment': [{'id': 479, 'fullpath': 'User Interface :: Toolkits/Libraries :: Qt', 'fullname': 'Qt', 'shortname': 'ui_qt'}], 'os': [{'id': 201, 'fullpath': 'Operating System :: Modern (Vendor-Supported) Desktop Operating Systems :: Linux', 'fullname': 'Linux', 'shortname': 'linux'}], 'developmentstatus': [{'id': 9, 'fullpath': 'Development Status :: 3 - Alpha', 'fullname': '3 - Alpha', 'shortname': 'alpha'}], 'database': [], 'audience': [], 'language': [{'id': 165, 'fullpath': 'Programming Language :: C++', 'fullname': 'C++', 'shortname': 'cpp'}], 'license': [{'id': 187, 'fullpath': 'License :: OSI-Approved Open Source :: BSD License', 'fullname': 'BSD License', 'shortname': 'bsd'}, {'id': 190, 'fullpath': 'License :: OSI-Approved Open Source :: Qt Public License (QPL)', 'fullname': 'Qt Public License (QPL)', 'shortname': 'qpl'}], 'topic': [{'id': 28, 'fullpath': 'Topic :: Communications :: Email', 'fullname': 'Email', 'shortname': 'email'}]}, 'labels': [], 'screenshots': [], 'creation_date': '2011-05-15', 'shortname': 'q-gps', 'forge': 'sourceforge', 'preferred_support_url': '', 'name': 'Q-GPS', 'url': 'https://sourceforge.net/p/q-gps/', 'external_homepage': 'https://q-gps.sourceforge.io', 'icon_url': None, 'developers': [{'url': 'https://sourceforge.net/u/ypoflyer/', 'name': 'LeiHongliang', 'username': 'ypoflyer'}], 'tools': [{'installable': False, 'url': '/p/q-gps/summary/', 'name': 'summary', 'mount_point': 'summary', 'sourceforge_group_id': 545929, 'mount_label': 'Summary', 'icons': {'24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'tool_label': 'Summary'}, {'installable': False, 'url': '/p/q-gps/files/', 'name': 'files', 'mount_point': 'files', 'mount_label': 'Files', 'icons': {'24': 'images/downloads_24.png', '48': 'images/downloads_48.png', '32': 'images/downloads_32.png'}, 'tool_label': 'Files'}, {'installable': False, 'url': '/p/q-gps/support/', 'name': 'support', 'mount_point': 'support', 'mount_label': 'Support', 'icons': {'24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'tool_label': 'Support'}, {'installable': True, 'url': '/p/q-gps/wiki/', 'name': 'wiki', 'mount_point': 'wiki', 'mount_label': 'Wiki', 'icons': {'24': 'images/wiki_24.png', '48': 'images/wiki_48.png', '32': 'images/wiki_32.png'}, 'tool_label': 'Wiki'}, {'installable': True, 'url': '/p/q-gps/support-requests/', 'name': 'tickets', 'mount_point': 'support-requests', 'mount_label': 'Support Requests', 'icons': {'24': 'images/tickets_24.png', '48': 'images/tickets_48.png', '32': 'images/tickets_32.png'}, 'tool_label': 'Tickets'}, {'installable': False, 'url': '/p/q-gps/reviews/', 'name': 'reviews', 'mount_point': 'reviews', 'mount_label': 'Reviews', 'icons': {'24': 'images/sftheme/24x24/blog_24.png', '48': 'images/sftheme/48x48/blog_48.png', '32': 'images/sftheme/32x32/blog_32.png'}, 'tool_label': 'Reviews'}, {'installable': False, 'url': '/p/q-gps/activity/', 'name': 'activity', 'mount_point': 'activity', 'mount_label': 'Activity', 'icons': {'24': 'images/admin_24.png', '48': 'images/admin_48.png', '32': 'images/admin_32.png'}, 'tool_label': 'Tool'}, {'installable': False, 'url': '/p/q-gps/mailman/', 'name': 'mailman', 'mount_point': 'mailman', 'mount_label': 'Mailing Lists', 'icons': {'24': 'images/forums_24.png', '48': 'images/forums_48.png', '32': 'images/forums_32.png'}, 'tool_label': 'Mailing Lists'}], 'short_description': 'This is my GPS navigation system software based on Qt. It supports shapefile map. ', 'preferred_support_tool': '', 'private': False}
